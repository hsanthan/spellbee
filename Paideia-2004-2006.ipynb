# %%
import textract
import PyPDF2
import numpy as np
import pandas as pd
from tika import parser
import tabula
import re
import requests
import os

# %%
keyid_inter = '9cfbf9ed-b6c0-4ab1-9762-9383fb15a5de'
keyid_col = '1c635859-2b31-41b2-9802-572347452d30'
keyid_med = '83de8977-c9be-4663-ab6a-0fb6b70641e2'

# %%
pdf = '/Users/hema/Downloads/SpellBee/Paideia-2004-2006.pdf'

# %% [markdown]
# tika /textract

# %%
txt = parser.from_file(pdf)

# %%
text = txt['content'].split('\n\n')
all_text = ''.join(text)

# %%
all_text
# Out:
# '\nlake\nThe Spelling ChampPaideia 2004-2006 TheSpellingChamp.com\nWebsite by Cole Shafer-RayPaideia 2004-2006 WordsThis word list is a supplement to the CWL(2004) and Spell It! (2007-2012) Paideia 2004 -over 3800 words\nPaideia 2005 -over 3900 words\nPaideia 2006 -over 4100 words\nChemistry Chemistry Chemistry \nPoe Words Poe Words Poe Words World Religions World Religions World Religions \nFolk Etymologies Folk Etymologies Folk Etymologies Del Español Del Español Del Español \nCrime & Punishment Crime & Punishment Thumbs Up & Thumbs Down Colorific! Colorific! Adversity & Calamity \nFabulous Words Fabulous Words Fabulous Words \nAll Dressed Up All Dressed Up All Dressed Up The Round Table The Round Table Down by the Sea \nPrefixes Rules! Prefixes Rules! Prefixes Rules! \nIt’s About Time It’s About Time It’s About Time \nFamous Words The Body Within The Body Within \nMood Swings Little Words Little Words Watership Down Watership Down Watership Down \nFood For Thought Food For Thought Food For Thought \nNorthern Lights Northern Lights Northern Lights The Ties That Bind The Ties That Bind Field of Champions \nEnglish, Latin, & Greek English, Latin, & Greek * All new words English, Latin, & Greek War & Peace War & Peace War & Peace \nSpelling Counts Spelling Counts Spelling Counts Shake A Leg Politics & Government Politics & Government \nSports & Games Sports & Games Sports & Games Cognates Cognates Cognates \nHitting the Books Hitting the Books Hitting the Books That’s Entertainment That’s Entertainment That’s Entertainment COLORIFIC! BEGINNING \nslate \ndrab \ncherry \nbrassy \niceblink \nbleach \nbrownstone \nstrawberry \nbuff \namber \ncharcoal \nshiner \nginger \nrosy \nkelly \nivory \nspruce \nneon \naqua \nraven \nruddy \nchocolate \nultramarine \npastel \nrusset \nrouge \ntangerine indigo \nroan INTERMEDIATE \nbronze \nemerald \ngilded \ncoral \ncardinal \nscarlet \npearly \ncanary \ntopaz \nsalmon \nauburn \nfiery \nteal \nagate \ntinge \nfoxing \nlivid \nburgundy \nazure \ndun \number \nlurid \nhenna \ntotem \nsapphire melanoma \ntawny \nebonize \nmauve \nsallow \nsaffron \ncolorimeter \nmagenta \nwheaten \ncarmine \ntincture \nchampagne \nalabaster \nalpenglow \nbeige \nchromometer \nchroma \ntaupe \nchromatosis \nverdure \nchlorosis \nonyx \nforsythia \nsilhouette \necru ADVANCED \npied \nvariegated sepia \ncordovan \ncyanosis \nolivaceous \npiebald \nrembrandt \nroseola \nsorrel \nguernsey \npompeii \nflammeous \npsychedelic \nvinaceous \natrament \nviridity \nhoary \narbutus \nplumbeous \nkillarney \nviolaceous \nplatina \nanaglyph \nverdigris \nhemochromatosis \nviridescent \nacrocyanosis \nfulvous \npitchblende \nhematochrome titian \nchrysochlorous \nadustiosis \nchloasma \nbrunneous \nfuliginous \ncinereal \nrutilant \nrubefacient \nsmaragdine \nbilirubin \nxanthic \niodopsin \nerythrophobia \nroux \nbardiglio \nponceau \nwoad \nerythropsia \nchiaroscurist \npongee \necchymosis \nphilamot \nphaeochrous \nwiesenboden \nchernozem \ntilleul \nemailTheSpellingChamp.comCHEMISTRY BEGINNING \nbond \nsalt \nlime \nrare \nsupercool \nsubshell \nsoda \nboiling \ncolorless \ntasteless \nbasic \nacid \nbeaker \nconstant \ncombust \nideal \nantacid \nemit \ninvert \ncubic \nnormality \nnoble \norganic \nfixation \nliquid \nalloy \nozone \nboric \ndecompose phase \ndensity \ncritical \ncondense \nsolvent \nsublime \naromatic \nplasma \novervoltage \nevaporate \ncarbide \npeptide \ncorrode \ndilute \nreactant \nmolar \ntrans \nsucrose \nglucose \ncarbonate \nvaporize \nnitrite \ndiatomic \ndipolar \nhydrate \nmineralize \nadhesion \norbital \natmospheric \nthermochemical \nelectrochemical diamagnetic \nvolumetric \nhydroxide \nsaturated \nprotein \nionize \ndative \ngravimetric \ncalorimetric \npolarimetric \nfluoride INTERMEDIATE \nresidue \ngaseous \nkinetic \nmolecular \nintermolecular \nplanar \nprecipitate \noxidize \nmethanize \nneutralize \nvolatile \ntriclinic \nchromic \nmercuric \nisotopic \nisoelectronic \nelectroly ...

# %%
all_text = all_text.split('\n')

# %%
all_text[1548]
# Out:
# 'stem '

# %%
all_text.index('slate ')
# Out:
# 22

# %%
df = pd.DataFrame(all_text[22:], columns=['Word'])

# %%
len(df)
# Out:
# 5111

# %%
df = df.iloc[23:,:]

# %%
print(len(all_text))
print(len(df))
# Out:
# 5133
# 5088

# %%
df1 = df.applymap(lambda x: x.replace('\n',''))
df1.dropna(inplace=True)
df1 = df.applymap(lambda x: x.strip())
len(df1
   )
# Out:
# 5111

# %%
df1 = df1[(df1['Word'].str.lower()!='paideia 2004-2006')&(df1['Word']!='The Spelling Champ')&
          (df1['Word']!='TheSpellingChamp.comWebsite by Cole Shafer-Ray')&(df1['Word']!='Paideia 2004-2006 Words')&
          (df1['Word']!='This word list is a supplement to the CWL(2004) and Spell It! (2007-2012)')&
         (df1['Word']!='Paideia 2004')&(df1['Word']!='TheSpellingChamp.com')]
         
#(df1['Word']!='
len(df1)
# Out:
# 5111

# %%
df1
# Out:
#                              Word Meaning
# 0                           slate
# 1                            drab
# 2                          cherry
# 3                          brassy
# 4                        iceblink
# ...                           ...     ...
# 5106                 ayuntamiento
# 5107                       cahier
# 5108                apparentement
# 5109  syssel TheSpellingChamp.com
# 5110
#
# [5111 rows x 2 columns]

# %%
df1 = df.applymap(lambda x: x.replace('TheSpellingChamp.com',''))

# %%
df1['Meaning'] = ''

# %%
words_without_meaning = df1[df1['Meaning']=='']['Word']
respE = [requests.get(f'https://www.dictionaryapi.com/api/v3/references/collegiate/json/{word}?key={keyid_col}') for word in words_without_meaning]

# %%
respE[0].json()
# Out:
# [{'meta': {'id': 'slate:1',
#    'uuid': 'c6cd1dbf-648f-4111-9a1c-b80dd9b1ff31',
#    'sort': '194468400',
#    'src': 'collegiate',
#    'section': 'alpha',
#    'stems': ['slate', 'slatelike', 'slates'],
#    'offensive': False},
#   'hom': 1,
#   'hwi': {'hw': 'slate',
#    'prs': [{'mw': 'ˈslāt',
#      'sound': {'audio': 'slate001', 'ref': 'c', 'stat': '1'}}]},
#   'fl': 'noun',
#   'def': [{'sseq': [[['sense',
#        {'sn': '1',
#         'dt': [['text',
#           '{bc}a piece of construction material (such as laminated rock) prepared as a shingle for roofing and siding']]}]],
#      [['sense',
#        {'sn': '2',
#         'dt': [['text',
#           '{bc}a dense fine-grained metamorphic rock produced by the compression of various sediments (such as clay or shale) so as to develop a characteristic cleavage']]}]],
#      [['sense',
#        {'sn': '3',
#         'dt': [['text', '{bc}a tablet (as of slate) used for writing on']]}]],
#      [['sense',
#        {'sn': '4 a',
#         'dt': [['text', '{bc}a written or unwritten record (as of deeds) '],
#          ['vis', [{'t': 'started with a clean {wi}slate{/wi}'}]]]}],
#       ['sense',
#        {'sn': 'b',
#         'dt': [['text',
#           '{bc}a list of candidates for nomination or election']]}]],
#      [['sense', {'sn': '5 a', 'dt': [['text', '{bc}a dark purplish gray']]}],
#       ['sense',
#        {'sn': 'b',
#         'dt': [['text',
#           '{bc}any of various grays similar in color to common roofing {a_link|slates}']]}]]]}],
#   'uros': [{'ure': 'slate', 'fl': 'adjective'},
#    {'ure': 'slate*like',
#     'prs': [{'mw': 'ˈslāt-ˌlīk',
#       'sound': {'audio': 'slate002', 'ref': 'c', 'stat': '1'}}],
#     'fl': 'adjective'}],
#   'et': [['text',
#     'Middle English {it}sclate, slate{/it}, from Anglo-French {it}*esclat{/it}, from {it}esclater{/it} to splinter, break off, of Germanic origin; akin to Old High German ze{it}sleizzen, slīzan{/it} to tear apart {ma}{mat|slit|}{/ma}']],
#   'date': '14th century{ds||1||}',
#   'shortdef': ['a piece of construction material (such as laminated rock) prepared as a shingle for roofing and siding',
#    'a dense fine-grained metamorphic rock produced by the compression of various sediments (such as clay or shale) so as to develop a characteristic cleavage',
#    'a tablet (as of slate) used for writing on']},
#  {'meta': {'id': 'slate:2',
#    'uuid': '03a6e9b7-921e-4f82-8845-dba6c2d9eba7',
#    'sort': '194468500',
#    'src': 'collegiate',
#    'section': 'alpha',
#    'stems': ['slate', 'slated', 'slates', 'slating'],
#    'offensive': False},
#   'hom': 2,
#   'hwi': {'hw': 'slate'},
#   'fl': 'verb',
#   'ins': [{'if': 'slat*ed'}, {'if': 'slat*ing'}],
#   'def': [{'vd': 'transitive verb',
#     'sseq': [[['sense',
#        {'sn': '1',
#         'dt': [['text',
#           '{bc}to cover (something) with slate or a {a_link|slatelike} substance '],
#          ['vis', [{'t': '{wi}slate{/wi} a roof'}]]]}]],
#      [['sense',
#        {'sn': '2',
#         'dt': [['text',
#           '{bc}to designate (someone or something) for a specified purpose or action occurring especially at a fixed time '],
#          ['vis',
#           [{'t': 'was {it}slated{/it} to direct the play'},
#            {'t': 'The new model is {wi}slated{/wi} {gloss}=scheduled{/gloss} for release early next year.'}]]]}]]]}],
#   'date': '15th century{ds||1||}',
#   'shortdef': ['to cover (something) with slate or a slatelike substance',
#    'to designate (someone or something) for a specified purpose or action occurring especially at a fixed time']},
#  {'meta': {'id': 'slate:3',
#    'uuid': 'a5170f87-322e-4420-bc37-6a2996682a63',
#    'sort': '194468600',
#    'src': 'collegiate',
#    'section': 'alpha',
#    'stems': ['slate', 'slated', 'slates', 'slating'],
#    'offensive': False},
#   'hom': 3,
#   'hwi': {'hw': 'slate'},
#   'fl': 'verb',
#   'ins': [{'if': 'slat*ed'}, {'if': 'slat*ing'}],
#   'def': [{'vd': 'transitive verb',
#     'sseq': [[['sense',
#        {'sn': '1', 'dt': [['text', '{bc}to thrash or pummel severely']]}]],
#      [['sense',
#        {'sn': '2',
#         'sls': ['chiefly British'],
#         'dt': [['text', '{bc}to criticize or censure severely']]}]]]}],
#   'et': [['text', 'probably alteration of {et_link|slat:1|slat:1}']],
#   'date': '1825{ds||1||}',
#   'shortdef': ['to thrash or pummel severely',
#    'to criticize or censure severely']},
#  {'meta': {'id': 'blank slate',
#    'uuid': '12761fc0-740f-4d52-ad31-50db567e08c6',
#    'sort': '020267500',
#    'src': 'collegiate',
#    'section': 'alpha',
#    'stems': ['blank slate'],
#    'offensive': False},
#   'hwi': {'hw': 'blank slate'},
#   'fl': 'noun',
#   'def': [{'sseq': [[['sense',
#        {'dt': [['text', '{bc}{sx|tabula rasa||}']]}]]]}],
#   'date': '1886',
#   'shortdef': ['tabula rasa']},
#  {'meta': {'id': 'slate black',
#    'uuid': 'ca365966-82ed-4bb8-be20-3012b9e44467',
#    'sort': '194468700',
#    'src': 'collegiate',
#    'section': 'alpha',
#    'stems': ['slate black', 'slate blacks'],
#    'offensive': False},
#   'hwi': {'hw': 'slate black'},
#   'fl': 'noun',
#   'def': [{'sseq': [[['sense',
#        {'dt': [['text', '{bc}a nearly neutral slightly purplish black']]}]]]}],
#   'date': '1887',
#   'shortdef': ['a nearly neutral slightly purplish black']},
#  {'meta': {'id': 'slate blue',
#    'uuid': '334c4f44-3697-4711-8924-d97e2d0de43a',
#    'sort': '194468800',
#    'src': 'collegiate',
#    'section': 'alpha',
#    'stems': ['slate blue', 'slate blues'],
#    'offensive': False},
#   'hwi': {'hw': 'slate blue'},
#   'fl': 'noun',
#   'def': [{'sseq': [[['sense',
#        {'dt': [['text', '{bc}a grayish-blue color']]}]]]}],
#   'date': '1796',
#   'shortdef': ['a grayish-blue color']},
#  {'meta': {'id': 'clean slate',
#    'uuid': 'c0c37e38-daf4-4f33-9f5d-a302d37b0dda',
#    'sort': '3003351000',
#    'src': 'ld',
#    'section': 'idioms',
#    'stems': ['clean slate'],
#    'offensive': False},
#   'hwi': {'hw': 'clean slate'},
#   'fl': 'noun',
#   'def': [{'sseq': [[['sense',
#        {'dt': [['text',
#           "{bc}a person's record (as from a school or a job) that shows no evidence of any problems, broken rules, etc. {bc}a clean record "],
#          ['vis',
#           [{'t': 'Everyone who comes to this school starts with a {it}clean slate{/it}.'}]]]}]]]}],
#   'shortdef': ["a person's record (as from a school or a job) that shows no evidence of any problems, broken rules, etc. : a clean record"]},
#  {'meta': {'id': 'slate gray',
#    'uuid': '03036d9f-884e-4c46-a8e4-e9c81a5f7a47',
#    'sort': '3017720000',
#    'src': 'ld',
#    'section': 'idioms',
#    'stems': ['slate gray'],
#    'offensive': False},
#   'hwi': {'hw': 'slate gray'},
#   'fl': 'noun',
#   'def': [{'sseq': [[['sense',
#        {'dt': [['text', '{bc}a bluish-gray color']]}]]]}],
#   'shortdef': ['a bluish-gray color']},
#  {'meta': {'id': 'wipe the slate clean',
#    'uuid': 'eb6cd601-36b2-46b4-9b73-e048b568e638',
#    'sort': '3022692000',
#    'src': 'ld',
#    'section': 'idioms',
#    'stems': ['wipe the slate clean'],
#    'offensive': False},
#   'hwi': {'hw': 'wipe the slate clean'},
#   'fl': 'idiom',
#   'def': [{'sseq': [[['sense',
#        {'dt': [['text',
#           '{bc}to forget all the things that have happened or been done and start doing something again {bc}to start again from the very beginning '],
#          ['vis',
#           [{'t': 'She wishes she could {it}wipe the slate clean{/it} and start over in a different career.'}]]]}]]]}],
#   'shortdef': ['to forget all the things that have happened or been done and start doing something again : to start again from the very beginning']}]

# %%
words = df1

# %%
#def get_word_meaning_mw( words, respE):

all_rows = []
missing_words = []
words_without_meaning = words[words['Meaning']=='']['Word']
# respE = [requests.get(f'https://www.dictionaryapi.com/api/v3/references/collegiate/json/{word}?key={keyid_col}') for word in words_without_meaning]

all_rows = []
meta_dict = {}
meta_cnt = 0
set_miss_word_dict = {}
#filename = 'L1A'
#filepath = file #'/Users/hema/Downloads'
print(all_rows)
aud_cnt = 1
for idx, res in enumerate(respE):   
    ids = ''
    stems = ''
    fls = ''
    hwis = ''
    shdef = ''
    ets = ''
    prss = ''
    audios = ''
    audio = []
    audio_filename = ''
    try:
        data = (res.json())
        #print(data)
        print('=============================================')
        if "'meta'" not in str(data):
              missing_words.append(words.iloc[idx,:].values[0])
        else :
            for meta in data:
                    aud_cnt += 1
                    for key, item in meta.items():
                        meta_dict[key] = item 
                        for key, item in meta_dict.items():
                            if key=='meta':
                                for k,i in item.items():
                                    if k=='id':
                                        ids= i
                                    if k=='stems':
                                        stems = i

                            if key=='fl':
                                fls = item

                            if key=='hwi':

                                for k,i in item.items():
                                    if k=='prs':                            
                                        prs_keys = (i[0].items())
                                        for key,pro in prs_keys:
                                            if key=='mw':
                                                prss=pro
                                            if key=='sound':
                                                audios=pro['audio']
                                                aud = pro['audio']
                                                if re.match('^gg*', aud):
                                                    fol = 'gg'
                                                elif re.match('^[a-zA-Z]', aud):
                                                    fol = aud[0]
                                                else:
                                                    fol = 'number'




                            if key=='shortdef':
                                if len(item) != 0:
                                    shdef = item[0]


                            if key=='et':
                                if len(item) != 0:
                                    ets = item[0][1]

    #                 row = (ids, stems, fls, prss, audio_link, shdef, ets, audio_filepath)
                    #row = (ids, prss, ets, shdef)
                    row = (ids, shdef)
                    #print(row)
                    all_rows.append(row)
            #print(all_rows)
    except Exception as e:
        print(e)
        continue

df_all = pd.DataFrame(all_rows, columns=['Word', 'Short Definition']) 

#add the meaning to the word df
#for w in words_without_meaning:
    #print(df_all.loc[df_all['Word']==w,'Short Definition'].values[0])
 #   words.loc[words['Word']==w,'Meaning'] = df_all.loc[df_all['Word']==w,'Short Definition'].values
#return words, df_all

#write the meaning to the source excel/csv file

df_all
# Out:
# []
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# ...
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# Expecting value: line 1 column 1 (char 0)
#                 Word                                   Short Definition
# 0            slate:1  a piece of construction material (such as lami...
# 1            slate:2  to cover (something) with slate or a slatelike...
# 2            slate:3                       to thrash or pummel severely
# 3        blank slate                                        tabula rasa
# 4        slate black           a nearly neutral slightly purplish black
# ...              ...                                                ...
# 8504       dirigisme         economic planning and control by the state
# 8505     Anschluss:f  union —used especially in reference to the for...
# 8506         khedive  a ruler of Egypt from 1867 to 1914 governing a...
# 8507  arrondissement  an administrative district of some large Frenc...
# 8508          cahier  a report or memorial concerning policy especia...
#
# [8509 rows x 2 columns]

# %%
df_all
# Out:
#                 Word                                   Short Definition
# 0            slate:1  a piece of construction material (such as lami...
# 1            slate:2  to cover (something) with slate or a slatelike...
# 2            slate:3                       to thrash or pummel severely
# 3        blank slate                                        tabula rasa
# 4        slate black           a nearly neutral slightly purplish black
# ...              ...                                                ...
# 8504       dirigisme         economic planning and control by the state
# 8505     Anschluss:f  union —used especially in reference to the for...
# 8506         khedive  a ruler of Egypt from 1867 to 1914 governing a...
# 8507  arrondissement  an administrative district of some large Frenc...
# 8508          cahier  a report or memorial concerning policy especia...
#
# [8509 rows x 2 columns]

# %%
df_all.fillna('Meaning', inplace=True)

# %%
#words_without_meaning
for w in words_without_meaning:
    print(w)
print(df_all[['Word','Short Definition']].values)
# Out:
# aborad
# alyssum
# anemochore
# apodictic
# Balearic
# basenji
# belonoid
# carnauba
# coadunate
# composite
# conticent
# corposant
# corticoline
# craquelure
# empennage
# engastrimythic
# fanfaronade
# filiopietistic
# gastrilegous
# gerrymander
# Gomorrah
# heldentenor
# hippie
# hyponychium
# innominate
# intussusception
# isapostolic
# Latino
# longicollous
# Lubavitcher
# lumbriciform
# marquisette
# Merovingian
# mithridatism
# mouchoir
# Nigerois
# obtenebrate
# oximeter
# parrhesia
# parvitude
# pignorate
# plasmoptysis
# platina
# pulsatance
# pursuivant
# Ranunculus
# roborant
# sarwan
# saxicolous
# scaphocephaly
# schwarmerei
# sciapodous
# Shaviana
# sibilance
# silicicolous
# solecism
# solipsistic
# souchong
# splanchnic
# stradiot
# syringeal
# tabard
# tanistry
# theodicy
# tichodrome
# timoneer
# tinnitus
# toile
# trepanation
# trimolecular
# vimineous
# vinegarroon
# vitrophyre
# xenial
# [['alyssum'
#   'any of a genus (Alyssum) of Eurasian herbs of the mustard family with small usually yellow racemose flowers —called also madwort']
#  ['sweet alyssum'
#   'a widely cultivated European herb (Lobularia maritima) of the mustard family having narrow leaves and clusters of small fragrant usually white or pink flowers']
#  ['apodictic'
#   'expressing or of the nature of necessary truth or absolute certainty']
#  ['Balearic Islands:g'
#   'islands of eastern Spain in the western Mediterranean Sea']
#  ['basenji'
#   'any of a breed of small curly-tailed dogs of African origin that do not bark']
#  ['carnauba'
#   'a fan-leaved palm (Copernicia prunifera synonym C. cerifera) of Brazil that has an edible root and yields a useful leaf fiber and carnauba wax']
#  ['carnauba wax'
#   'a hard brittle high-melting wax obtained from the leaves of the carnauba palm and used chiefly in polishes']
#  ['composite:1' 'made up of distinct parts or elements : such as']
#  ['composite:2' 'something composite : compound']
#  ['composite:3' 'to make composite or into something composite']
#  ['composite function'
#   'a function whose values are found from two given functions by applying one function to an independent variable and then applying the second function to the result and whose domain consists of those values of the independent variable for which the result yielded by the first function lies in the domain of the second']
#  ['corposant' "saint elmo's fire"]
#  ['empennage' 'the tail assembly of an aircraft']
#  ['fanfaronade' 'empty boasting : bluster']
#  ['filiopietistic'
#   'of or relating to an often excessive veneration of ancestors or tradition']
#  ['gerrymander:1' 'the act or method of gerrymandering']
#  ['gerrymander:2'
#   'to divide or arrange (a territorial unit) into election districts in a way that gives one political party an unfair advantage : to subject to gerrymandering']
#  ['Gomorrah' 'a place notorious for vice and corruption']
#  ['Gomorrah:g'
#   'ancient city thought to be in the area now covered by the southwestern part of the Dead Sea']
#  ['heldentenor'
#   'a tenor with a powerful, dramatic voice well suited to heroic roles (as in Wagnerian operas)']
#  ['hippie'
#   'a usually young person who rejects the mores of established society (as by dressing unconventionally or favoring communal living) and advocates a nonviolent ethic; broadly : a long-haired unconventionally dressed young person']
#  ['innominate' 'having no name : unnamed; also : anonymous']
#  ['innominate artery' 'brachiocephalic artery']
#  ['innominate bone' 'hip bone']
#  ['innominate vein' 'brachiocephalic vein']
#  ['brachiocephalic artery'
#   'a short artery that arises from the arch of the aorta and divides into the carotid and subclavian arteries of the right side —called also innominate artery']
#  ['brachiocephalic vein'
#   'either of two large veins that occur one on each side of the neck, receive blood from the head and neck, and unite to form the superior vena cava —called also innominate vein']
#  ['intussusception' 'a drawing in of something from without: such as']
#  ['Latino' 'a native or inhabitant of Latin America']
#  ['Lubavitcher'
#   'a member of a Hasidic sect founded by Schneur Zalman of Lyady in the late 18th century']
#  ['marquisette'
#   'a sheer meshed fabric used for clothing, curtains, and mosquito nets']
#  ['Merovingian'
#   'of or relating to the first Frankish dynasty reigning from about a.d. 500 to 751']
#  ['Niger:g'
#   'river 2600 miles (4184 kilometers) long in western Africa flowing north from the Fouta Djallon region in Guinea, northeast through Mali, and southeast through Niger, then forming the border between Niger and Benin, and finally flowing southeast then south through Nigeria and into the Gulf of Guinea']
#  ['oximeter'
#   'a noninvasive medical device for measuring continuously or intermittently the degree of oxygen saturation of circulating blood or a localized region of tissue; especially : pulse oximeter']
#  ['pulse oximeter'
#   'a noninvasive medical device that utilizes spectrophotometry to measure the oxygen saturation of circulating arterial blood in an individual by determining the percentage of oxygenated hemoglobin pulsating through a network of blood capillaries by way of a sensor attached typically to a finger, toe, or earlobe']
#  ['platina' 'platinum']
#  ['pursuivant'
#   'an officer of arms ranking below a herald but having similar duties']
#  ['ranunculus'
#   'any of a large genus (Ranunculus of the family Ranunculaceae, the buttercup family) of chiefly perennial herbaceous plants with tuberous or fibrous roots and typically yellow, five-petaled, cup-shaped flowers and including one (R. asiaticus) of southeastern Europe and southwestern Asia widely cultivated for its white, yellow, pink, red, or orange flowers having multiple layers of petals']
#  ['saxicolous' 'inhabiting or growing among rocks']
#  ['schwarmerei' 'excessive sentiment']
#  ['sibilance' 'a sibilant quality or sound']
#  ['solecism'
#   'an ungrammatical combination of words in a sentence; also : a minor blunder in speech']
#  ['solipsistic'
#   'of, relating to, or characterized by solipsism or extreme egocentricity']
#  ['souchong' 'a tea made from the larger older leaves of the shoot']
#  ['Lapsang souchong'
#   'a souchong tea having a pronounced smoky flavor and aroma']
#  ['splanchnic' 'of or relating to the viscera : visceral']
#  ['tabard'
#   'a short loose-fitting sleeveless or short-sleeved coat or cape: such as']
#  ['theodicy'
#   "defense of God's goodness and omnipotence in view of the existence of evil"]
#  ['tinnitus'
#   'a sensation of noise (such as a ringing or roaring) that is typically caused by a bodily condition (such as a disturbance of the auditory nerve or wax in the ear) and usually is of the subjective form which can only be heard by the one affected']
#  ['toile'
#   'any of many plain or simple twill weave fabrics; especially : linen']
#  ['toile de Jouy'
#   'an 18th century French scenic pattern usually printed on cotton, linen, or silk in one color on a light ground; broadly : a similar printed fabric']
#  ["aide-toi, le ciel t'aidera:f"
#   'help yourself (and) heaven will help you : God helps those who help themselves']
#  ['trepan:1' 'to use a trephine on (the skull)']
#  ['trepan:4' 'entrap, lure']]

# %%
#df1.reset_index(inplace=True)
df_all.loc[4:6]
# Out:
#           Word                                   Short Definition
# 4  slate black           a nearly neutral slightly purplish black
# 5   slate blue                               a grayish-blue color
# 6  clean slate  a person's record (as from a school or a job) ...

# %%
len(df_all)
# Out:
# 8509

# %%
'''for w in words_without_meaning:
    #print(df_all.loc[df_all['Word']==w,'Short Definition'].values[0])
    words.loc[words['Word']==w,'Meaning'] = df_all.loc[df_all['Word']==w,'Short Definition'].values[0]'''
# Out:
# "for w in words_without_meaning:\n    #print(df_all.loc[df_all['Word']==w,'Short Definition'].values[0])\n    words.loc[words['Word']==w,'Meaning'] = df_all.loc[df_all['Word']==w,'Short Definition'].values[0]"

# %%
#df_all['Short Definition'].rename('Meaning', inplace=True)

# %%
#words = get_word_meaning_mw(df1, respE)
df_all.rename(columns={'Short Definition':'Meaning'}, inplace=True)

# %%
df_all
# Out:
#                 Word                                            Meaning
# 0            slate:1  a piece of construction material (such as lami...
# 1            slate:2  to cover (something) with slate or a slatelike...
# 2            slate:3                       to thrash or pummel severely
# 3        blank slate                                        tabula rasa
# 4        slate black           a nearly neutral slightly purplish black
# ...              ...                                                ...
# 8504       dirigisme         economic planning and control by the state
# 8505     Anschluss:f  union —used especially in reference to the for...
# 8506         khedive  a ruler of Egypt from 1867 to 1914 governing a...
# 8507  arrondissement  an administrative district of some large Frenc...
# 8508          cahier  a report or memorial concerning policy especia...
#
# [8509 rows x 2 columns]

# %%
df_merged = pd.merge(left=df1['Word'], right=df_all, how='outer', on='Word')

# %%
len(df_merged)
df_merged
# Out:
#                  Word                                            Meaning
# 0              slate                                                 NaN
# 1               drab                                                 NaN
# 2             cherry                                                 NaN
# 3             brassy                                                 NaN
# 4           iceblink                                                 NaN
# ...               ...                                                ...
# 13615       dirigisme         economic planning and control by the state
# 13616     Anschluss:f  union —used especially in reference to the for...
# 13617         khedive  a ruler of Egypt from 1867 to 1914 governing a...
# 13618  arrondissement  an administrative district of some large Frenc...
# 13619          cahier  a report or memorial concerning policy especia...
#
# [13620 rows x 2 columns]

# %%
writer = pd.ExcelWriter('Paideia-2004-2006.xlsx', engine='xlsxwriter')
for i in range(0,14000,500):
    df_merged.iloc[i:i+500,:].to_excel(writer, sheet_name=str(i+1)+'-'+ str(i+500), index=False)
writer.save()
