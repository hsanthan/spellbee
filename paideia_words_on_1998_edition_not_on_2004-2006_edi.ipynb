# %%
import textract
import PyPDF2
import numpy as np
import pandas as pd
from tika import parser
import tabula
import re
import requests
import os

# %%
keyid_inter = '9cfbf9ed-b6c0-4ab1-9762-9383fb15a5de'
keyid_col = '1c635859-2b31-41b2-9802-572347452d30'
keyid_med = '83de8977-c9be-4663-ab6a-0fb6b70641e2'

# %%
pdf = '/Users/hema/Downloads/SpellBee/paideia_words_on_1998_edition_not_on_2004-2006_edi.pdf'

# %% [markdown]
# pypdf

# %%
pdf_file = open(pdf, 'rb')
pdf_reader_obj = PyPDF2.PdfFileReader(pdf_file)
pdf_reader_obj.getNumPages()
# Out:
# 15

# %%
pg = pdf_reader_obj.getPage(5)
pg.extractText().split('\n')
# Out:
# [' ',
#  'TheSpellingBeeChamp.wordpress.com',
#  ' ',
#  'PAIDEIA ',
#  '1998',
#  ' ',
#  'extemporaneous',
#  ' ',
#  'extortion',
#  ' ',
#  'extradition',
#  ' ',
#  'extraneous',
#  ' ',
#  'extravaganza',
#  ' ',
#  'eyeball',
#  ' ',
#  'eyelid',
#  ' ',
#  'facial',
#  ' ',
#  'failure',
#  ' ',
#  'faineant',
#  ' ',
#  'faithful',
#  ' ',
#  'faja',
#  ' ',
#  'fajitas',
#  ' ',
#  'falconry',
#  ' ',
#  'fallow',
#  ' ',
#  'famine',
#  ' ',
#  'fancily',
#  ' ',
#  'fandangle',
#  ' ',
#  'fanfaronade',
#  ' ',
#  'fantoccini',
#  ' ',
#  'fasciculus',
#  ' ',
#  'fascism',
#  ' ',
#  'fasten',
#  ' ',
#  'fastigium',
#  ' ',
#  'fatigues',
#  ' ',
#  'fauna',
#  ' ',
#  'fealty',
#  ' ',
#  'febricula',
#  ' ',
#  'feis',
#  ' ',
#  'feliform',
#  ' ',
#  'fellow',
#  ' ',
#  'felony',
#  ' ',
#  'femur',
#  ' ',
#  'Fennoscandian',
#  ' ',
#  'fermata',
#  ' ',
#  'ferret',
#  ' ',
#  'ferric',
#  ' ',
#  'festoon',
#  ' ',
#  'fetter',
#  ' ',
#  'feudal',
#  ' ',
#  'few',
#  ' ',
#  'fianchetto',
#  ' ',
#  'fiddlehead',
#  ' ',
#  'fidgeting',
#  ' ',
#  'fielder',
#  ' ',
#  'fiercest',
#  ' ',
#  'fiery',
#  ' ',
#  'fiesta',
#  ' ',
#  'fifth',
#  ' ',
#  'figurine',
#  ' ',
#  'filamentary',
#  ' ',
#  'filibuster',
#  ' ',
#  'filiopietistic',
#  ' ',
#  'filmography',
#  ' ',
#  'filmscript',
#  ' ',
#  'finery',
#  ' ',
#  'finial',
#  ' ',
#  'firepower',
#  ' ',
#  'firkin',
#  ' ',
#  'fishgig',
#  ' ',
#  'fisticuffs',
#  ' ',
#  'fistula',
#  ' ',
#  'fixation',
#  ' ',
#  'flaccid',
#  ' ',
#  'flagellate',
#  ' ',
#  'flambeau',
#  ' ',
#  'flamingo',
#  ' ',
#  'flammeous',
#  ' ',
#  'flange',
#  ' ',
#  'flashback',
#  ' ',
#  'flautino',
#  ' ',
#  'fleabane',
#  ' ',
#  'fleer',
#  ' ',
#  'fleet',
#  ' ',
#  'fletching',
#  ' ',
#  'flimflam',
#  ' ',
#  'Flinders',
#  ' ',
#  'floccillation',
#  ' ',
#  'flock',
#  ' ',
#  'floodlight',
#  ' ',
#  'flora',
#  ' ',
#  'floreted',
#  ' ',
#  'floruit',
#  ' ',
#  'floss',
#  ' ',
#  'flotilla',
#  ' ',
#  'flotsam',
#  ' ',
#  'flouncing',
#  ' ',
#  'flounder',
#  ' ',
#  'floweret',
#  ' ',
#  'flunk',
#  ' ',
#  'fluoride',
#  ' ',
#  'fluster',
#  ' ',
#  'flypaper',
#  ' ',
#  'foil',
#  ' ',
#  'foliage',
#  ' ',
#  'foliation',
#  ' ',
#  'folio',
#  ' ',
#  'folksiness',
#  ' ',
#  'folletto',
#  ' ',
#  'follicle',
#  ' ',
#  'Fomorian',
#  ' ',
#  'foolocracy',
#  ' ',
#  'footing',
#  ' ',
#  'forage',
#  ' ',
#  'foramen',
#  ' ',
#  'foreground',
#  ' ',
#  'forensics',
#  ' ',
#  'forestall',
#  ' ',
#  'forestry',
#  ' ',
#  'forgery',
#  ' ',
#  'formally',
#  ' ',
#  'former',
#  ' ',
#  'formula',
#  ' ',
#  'forsooth',
#  ' ',
#  'forsythia',
#  ' ',
#  'fortification',
#  ' ',
#  'fortnight',
#  ' ',
#  'fortress',
#  ' ',
#  'fourscore',
#  ' ',
#  'fourteen',
#  ' ',
#  'foxing',
#  ' ',
#  'frat',
#  ' ',
#  'fraud',
#  ' ',
#  'frazzle',
#  ' ',
#  'freckle',
#  ' ',
#  'fresh',
#  ' ',
#  'friar',
#  ' ',
#  'fricassee',
#  ' ',
#  'friction',
#  ' ',
#  'frieze',
#  ' ',
#  'frogged',
#  ' ',
#  'frolicsome',
#  ' ',
#  'frondescence',
#  ' ',
#  'fronds',
#  ' ',
#  'frontispiece',
#  ' ',
#  'fronton',
#  ' ',
#  'froufrou',
#  ' ',
#  'fughetta',
#  ' ',
#  'fuliginous',
#  ' ',
#  'fulsomely',
#  ' ',
#  'fulvous',
#  ' ',
#  'funambulist',
#  ' ',
#  'funereal',
#  ' ',
#  'funipendulous',
#  ' ',
#  'furbelow',
#  ' ',
#  'furlough',
#  ' ',
#  'furuncle',
#  ' ',
#  'fusillade',
#  ' ',
#  'fusilli',
#  ' ',
#  'fusion',
#  ' ',
#  'fustanella',
#  ' ',
#  'futurity',
#  ' ',
#  'gadroon',
#  ' ',
#  'gaffer',
#  ' ',
#  'gaggle',
#  ' ',
#  'gagtooth',
#  ' ',
#  'Galahad',
#  ' ',
#  'gallery',
#  ' ',
#  'Gallinazo',
#  ' ',
#  'gallows',
#  ' ',
#  'galvanic',
#  ' ',
#  'gambrel',
#  ' ',
#  'gammelost',
#  ' ',
#  'ganglion',
#  ' ',
#  'garderobe',
#  ' ',
#  'gargantuan',
#  ' ',
#  'garland',
#  ' ',
#  'garnish',
#  ' ',
#  'garrison',
#  ' ',
#  'garter',
#  ' ',
#  'garth',
#  ' ',
#  'gaseous',
#  ' ',
#  'gastric',
#  ' ',
#  'gastrilegous',
#  ' ',
#  'gastrocnemius',
#  ' ',
#  'gastroenterology',
#  ' ',
#  'gaufrette',
#  ' ',
#  'gazpacho',
#  ' ',
#  'gemmary',
#  ' ',
#  'gendarme',
#  ' ',
#  'gender',
#  ' ',
#  'genealogy',
#  ' ',
#  'general',
#  ' ',
#  'generate',
#  ' ',
#  'genius',
#  ' ',
#  'genocide',
#  ' ',
#  'genre',
#  ' ',
#  'genteel',
#  ' ',
#  'gentle',
#  ' ',
#  'gentry',
#  ' ',
#  'genuflect',
#  ' ',
#  'genus',
#  ' ',
#  'geochrony',
#  ' ',
#  'geranium',
#  ' ',
#  'geriatrics',
#  ' ',
#  'germane',
#  ' ',
#  'germinate',
#  ' ',
#  'gerontology',
#  ' ',
#  'gerrymander',
#  ' ',
#  'gestalt',
#  ' ',
#  'gestapo',
#  ' ',
#  'giaour',
#  ' ',
#  'gibbet',
#  ' ',
#  'gigot',
#  ' ',
#  'gilded',
#  ' ',
#  'ginglymus',
#  ' ',
#  'gird',
#  ' ',
#  'glaucous',
#  ' ',
#  'glima',
#  ' ',
#  'glimpse',
#  ' ',
#  'glistened',
#  ' ',
#  'glittering',
#  ' ',
#  'glossal',
#  ' ',
#  'glossolalia',
#  ' ',
#  'glottology',
#  ' ',
#  'glucocorticoid',
#  ' ',
#  'glutinous',
#  ' ',
#  'glycerol',
#  ' ',
#  'glycogen',
#  ' ',
#  'gnats',
#  ' ',
#  'gnomic',
#  ' ',
#  'gnosis',
#  ' ',
#  'goal',
#  ' ',
#  'golem',
#  ' ',
#  '']

# %% [markdown]
# #tabula

# %%
df = tabula.read_pdf(pdf)
# Out:
# 'pages' argument isn't specified.Will extract only from page 1 by default.

# %%
df
# Out:
# [                           Unnamed: 0   PAIDEIA 1998      Unnamed: 1
#  0                                 NaN            NaN             NaN
#  1   TheSpellingBeeChamp.wordpress.com            NaN             NaN
#  2                    abalone affinity     amphibious            aqua
#  3                   abdicate afflatus     amphoteric         aqueous
#  4                  abduction agalloch     amygdaline        aquiline
#  5                      ablution agape       anabasis       arabesque
#  6                      abnormal agate    anachronism       arachnoid
#  7                        aborad aggie       anaglyph  arachnophagous
#  8            aboriginally agglutinate      anamnesis   arboriculture
#  9                absolution aggregate        anarchy         arbutus
#  10                abstention agnostic    anastomosis         arcaded
#  11                     academe agonal       anathema          arcane
#  12               academia agrarianism       ancestor         archaic
#  13               academician agronomy        anchovy       archangel
#  14                    acanthus ahimsa        ancient         archery
#  15                   accipiter ahorse        ancilla    architecture
#  16            acclamation aiguillette        andante      architrave
#  17              accommodation aileron  anemobiagraph       archizoic
#  18                 accomplice Ailurus     anemochore          argent
#  19                 accretionary aioli      anemology        argonaut
#  20                  accumulate aition       anglaise         arietta
#  21                   acedia alabaster          angst          armada
#  22                 acetabulum alchemy      anhydrous       armadillo
#  23                      acetic alcove  animadversion       armaments
#  24                   acetone aldehyde        animism        armature
#  25             acetylcholine alderman        anionic         armiger
#  26                acharya aldosterone         anneal       armistice
#  27                  Achillean alembic     annexation         arrears
#  28             achondroplasia alfalfa    anniversary        arrestee
#  29                      acicula algid        annulet  arrondissement
#  30                      acolyte alias           anon         arsenic
#  31                    acoustics alibi      anschluss           arson
#  32                acrocyanosis alison        Antaean          artery
#  33                  acrolect alkaline     antagonist       Arthurian
#  34                    actinide alkane           ante      articulate
#  35                   adder allotropic     antebellum       artillery
#  36                    adherend allure     antecessor   aryepiglottic
#  37                       adios alpaca   antediluvian            aryl
#  38              adjournment alpenglow       antenati       ascension
#  39             adminicle alstroemeria     anticlimax        asphodel
#  40                admonish altarpiece    antiquarian           aspic
#  41                    adobe altiplano      antiquity   assassination
#  42                     adobo alveolar       aoristic         assault
#  43                adolescence alyssum          aorta        assemble
#  44                     Adonis amalgam        aparejo      assignment
#  45                   adonize amandine        aphasia          assisi
#  46                   adustiosis amass      apodictic        asterisk
#  47                adversary amaurosis     Apollonian      astrologer
#  48                aebleskive ambrosia       apostate      asynchrony
#  49                 aerodromics ambush        apostle           atlas
#  50             aerodynamic amercement     apotheosis       atmogenic
#  51                aerolithology amigo    apparatchik     atmospheric
#  52                   aeronautic amine  apparentement        atrament
#  53                   aerosol ammoniac    appeasement          atrium
#  54             Aesculapian ammunition      appellate       atrocious
#  55                      Aesir amnesty     appetitost         atrophy
#  56                   Aesopian amorino      appliquer         attaboy
#  57                affidavit amorphous      apprehend      attachable]

# %% [markdown]
# tika /textract

# %%
txt = parser.from_file(pdf)

# %%
text = txt['content'].split('\n\n')
text
# Out:
# ['',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '\nPaideia words on 1998 edition not on 2004-2006 edition',
#  '\n \nTheSpellingBeeChamp.wordpress.com ',
#  'PAIDEIA WORDS ON 1998 EDITION NOT ON 2004-2006 EDITION ',
#  'aborad ',
#  'alyssum ',
#  'anemochore ',
#  'apodictic ',
#  'Balearic ',
#  'basenji ',
#  'belonoid ',
#  'carnauba ',
#  'coadunate ',
#  'composite ',
#  'conticent ',
#  'corposant ',
#  'corticoline ',
#  'craquelure ',
#  'empennage ',
#  'engastrimythic ',
#  'fanfaronade ',
#  'filiopietistic ',
#  'gastrilegous ',
#  'gerrymander ',
#  'Gomorrah ',
#  'heldentenor ',
#  'hippie ',
#  'hyponychium ',
#  'innominate ',
#  'intussusception ',
#  'isapostolic ',
#  'Latino ',
#  'longicollous ',
#  'Lubavitcher ',
#  'lumbriciform ',
#  'marquisette ',
#  'Merovingian ',
#  'mithridatism ',
#  'mouchoir ',
#  'Nigerois ',
#  'obtenebrate ',
#  'oximeter ',
#  'parrhesia ',
#  'parvitude ',
#  'pignorate ',
#  'plasmoptysis ',
#  'platina ',
#  'pulsatance ',
#  'pursuivant ',
#  'Ranunculus ',
#  'roborant ',
#  'sarwan ',
#  'saxicolous ',
#  'scaphocephaly ',
#  'schwarmerei ',
#  'sciapodous ',
#  'Shaviana ',
#  'sibilance ',
#  'silicicolous ',
#  'solecism ',
#  'solipsistic ',
#  'souchong ',
#  'splanchnic ',
#  'stradiot ',
#  'syringeal ',
#  'tabard ',
#  'tanistry ',
#  'theodicy ',
#  'tichodrome ',
#  'timoneer ',
#  'tinnitus ',
#  'toile ',
#  'trepanation ',
#  'trimolecular ',
#  'vimineous ',
#  'vinegarroon ',
#  'vitrophyre ',
#  'xenial',
#  '\n']

# %%
df = pd.DataFrame(text, columns=['Word'])

# %%
df1 = df.applymap(lambda x: x.replace('\n',''))
df1.dropna(inplace=True)
df1 = df.applymap(lambda x: x.strip())
len(df1
   )
# Out:
# 100

# %%
df1 = df1[df1['Word']!='']

# %%
df1[df1['Word']=='TheSpellingBeeChamp.wordpress.com ']
# Out:
# Empty DataFrame
# Columns: [Word]
# Index: []

# %%
df1[df1['Word'].str.lower()!='paideia 1998']
# Out:
#              Word
# 0
# 1
# 2
# 3
# 4
# ...           ...
# 3332      zoology
# 3333  Zoroastrian
# 3334     zugzwang
# 3335
# 3336
#
# [3321 rows x 1 columns]

# %%
len(df1)
# Out:
# 100

# %%
df1 = df1[(df1['Word'].str.lower()!='paideia words on 1998 edition not on 2004-2006 edition')&(df1['Word']!='TheSpellingBeeChamp.wordpress.com')&(df1['Word'].str.lower()!='')]
#(df1['Word']!='
len(df1)
# Out:
# 74

# %%
df1['Meaning'] = ''
df1
# Out:
#             Word Meaning
# 25        aborad
# 26       alyssum
# 27    anemochore
# 28     apodictic
# 29      Balearic
# ..           ...     ...
# 94  trimolecular
# 95     vimineous
# 96   vinegarroon
# 97    vitrophyre
# 98        xenial
#
# [74 rows x 2 columns]

# %%
words_without_meaning = df1[df1['Meaning']=='']['Word']
respE = [requests.get(f'https://www.dictionaryapi.com/api/v3/references/collegiate/json/{word}?key={keyid_col}') for word in words_without_meaning]

# %%
respE[0].json()
# Out:
# ['aborted',
#  'aboral',
#  'aboard',
#  'Tabora',
#  'abort',
#  'aborts',
#  'abrade',
#  'abound',
#  'aborter',
#  'jaborandi',
#  'abraded',
#  'aborally',
#  'abrader',
#  'rasboras',
#  'abrades',
#  'elaborated',
#  'aborters',
#  'jaborandis',
#  'aborting',
#  'Deborah']

# %%
words = df1

# %%
#def get_word_meaning_mw( words, respE):

all_rows = []
missing_words = []
words_without_meaning = words[words['Meaning']=='']['Word']
# respE = [requests.get(f'https://www.dictionaryapi.com/api/v3/references/collegiate/json/{word}?key={keyid_col}') for word in words_without_meaning]

all_rows = []
meta_dict = {}
meta_cnt = 0
set_miss_word_dict = {}
#filename = 'L1A'
#filepath = file #'/Users/hema/Downloads'
print(all_rows)
aud_cnt = 1
for idx, res in enumerate(respE):   
    ids = ''
    stems = ''
    fls = ''
    hwis = ''
    shdef = ''
    ets = ''
    prss = ''
    audios = ''
    audio = []
    audio_filename = ''
    data = (res.json())
    #print(data)
    print('=============================================')
    if "'meta'" not in str(data):
          missing_words.append(words.iloc[idx,:].values[0])
    else :
        for meta in data:
                aud_cnt += 1
                for key, item in meta.items():
                    meta_dict[key] = item 
                    for key, item in meta_dict.items():
                        if key=='meta':
                            for k,i in item.items():
                                if k=='id':
                                    ids= i
                                if k=='stems':
                                    stems = i

                        if key=='fl':
                            fls = item

                        if key=='hwi':

                            for k,i in item.items():
                                if k=='prs':                            
                                    prs_keys = (i[0].items())
                                    for key,pro in prs_keys:
                                        if key=='mw':
                                            prss=pro
                                        if key=='sound':
                                            audios=pro['audio']
                                            aud = pro['audio']
                                            if re.match('^gg*', aud):
                                                fol = 'gg'
                                            elif re.match('^[a-zA-Z]', aud):
                                                fol = aud[0]
                                            else:
                                                fol = 'number'




                        if key=='shortdef':
                            if len(item) != 0:
                                shdef = item[0]


                        if key=='et':
                            if len(item) != 0:
                                ets = item[0][1]

#                 row = (ids, stems, fls, prss, audio_link, shdef, ets, audio_filepath)
                #row = (ids, prss, ets, shdef)
                row = (ids, shdef)
                print(row)
                all_rows.append(row)
        #print(all_rows)

df_all = pd.DataFrame(all_rows, columns=['Word', 'Short Definition']) 

#add the meaning to the word df
for w in words_without_meaning:
    #print(df_all.loc[df_all['Word']==w,'Short Definition'].values[0])
    words.loc[words['Word']==w,'Meaning'] = df_all.loc[df_all['Word']==w,'Short Definition'].values
#return words, df_all

#write the meaning to the source excel/csv file
# Out:
# []
# =============================================
# =============================================
# ('alyssum', 'any of a genus (Alyssum) of Eurasian herbs of the mustard family with small usually yellow racemose flowers —called also madwort')
# ('sweet alyssum', 'a widely cultivated European herb (Lobularia maritima) of the mustard family having narrow leaves and clusters of small fragrant usually white or pink flowers')
# =============================================
# =============================================
# ('apodictic', 'expressing or of the nature of necessary truth or absolute certainty')
# =============================================
# ('Balearic Islands:g', 'islands of eastern Spain in the western Mediterranean Sea')
# =============================================
# ('basenji', 'any of a breed of small curly-tailed dogs of African origin that do not bark')
# =============================================
# =============================================
# ('carnauba', 'a fan-leaved palm (Copernicia prunifera synonym C. cerifera) of Brazil that has an edible root and yields a useful leaf fiber and carnauba wax')
# ('carnauba wax', 'a hard brittle high-melting wax obtained from the leaves of the carnauba palm and used chiefly in polishes')
# =============================================
# =============================================
# ('composite:1', 'made up of distinct parts or elements : such as')
# ('composite:2', 'something composite : compound')
# ('composite:3', 'to make composite or into something composite')
# ('composite function', 'a function whose values are found from two given functions by applying one function to an independent variable and then applying the second function to the result and whose domain consists of those values of the independent variable for which the result yielded by the first function lies in the domain of the second')
# =============================================
# =============================================
# ('corposant', "saint elmo's fire")
# =============================================
# =============================================
# =============================================
# ('empennage', 'the tail assembly of an aircraft')
# =============================================
# =============================================
# ('fanfaronade', 'empty boasting : bluster')
# =============================================
# ('filiopietistic', 'of or relating to an often excessive veneration of ancestors or tradition')
# =============================================
# =============================================
# ('gerrymander:1', 'the act or method of gerrymandering')
# ('gerrymander:2', 'to divide or arrange (a territorial unit) into election districts in a way that gives one political party an unfair advantage : to subject to gerrymandering')
# =============================================
# ('Gomorrah', 'a place notorious for vice and corruption')
# ('Gomorrah:g', 'ancient city thought to be in the area now covered by the southwestern part of the Dead Sea')
# =============================================
# ('heldentenor', 'a tenor with a powerful, dramatic voice well suited to heroic roles (as in Wagnerian operas)')
# =============================================
# ('hippie', 'a usually young person who rejects the mores of established society (as by dressing unconventionally or favoring communal living) and advocates a nonviolent ethic; broadly : a long-haired unconventionally dressed young person')
# =============================================
# =============================================
# ('innominate', 'having no name : unnamed; also : anonymous')
# ('innominate artery', 'brachiocephalic artery')
# ('innominate bone', 'hip bone')
# ('innominate vein', 'brachiocephalic vein')
# ('brachiocephalic artery', 'a short artery that arises from the arch of the aorta and divides into the carotid and subclavian arteries of the right side —called also innominate artery')
# ('brachiocephalic vein', 'either of two large veins that occur one on each side of the neck, receive blood from the head and neck, and unite to form the superior vena cava —called also innominate vein')
# =============================================
# ('intussusception', 'a drawing in of something from without: such as')
# =============================================
# =============================================
# ('Latino', 'a native or inhabitant of Latin America')
# =============================================
# =============================================
# ('Lubavitcher', 'a member of a Hasidic sect founded by Schneur Zalman of Lyady in the late 18th century')
# =============================================
# =============================================
# ('marquisette', 'a sheer meshed fabric used for clothing, curtains, and mosquito nets')
# =============================================
# ('Merovingian', 'of or relating to the first Frankish dynasty reigning from about a.d. 500 to 751')
# =============================================
# =============================================
# =============================================
# ('Niger:g', 'river 2600 miles (4184 kilometers) long in western Africa flowing north from the Fouta Djallon region in Guinea, northeast through Mali, and southeast through Niger, then forming the border between Niger and Benin, and finally flowing southeast then south through Nigeria and into the Gulf of Guinea')
# =============================================
# =============================================
# ('oximeter', 'a noninvasive medical device for measuring continuously or intermittently the degree of oxygen saturation of circulating blood or a localized region of tissue; especially : pulse oximeter')
# ('pulse oximeter', 'a noninvasive medical device that utilizes spectrophotometry to measure the oxygen saturation of circulating arterial blood in an individual by determining the percentage of oxygenated hemoglobin pulsating through a network of blood capillaries by way of a sensor attached typically to a finger, toe, or earlobe')
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# ('platina', 'platinum')
# =============================================
# =============================================
# ('pursuivant', 'an officer of arms ranking below a herald but having similar duties')
# =============================================
# ('ranunculus', 'any of a large genus (Ranunculus of the family Ranunculaceae, the buttercup family) of chiefly perennial herbaceous plants with tuberous or fibrous roots and typically yellow, five-petaled, cup-shaped flowers and including one (R. asiaticus) of southeastern Europe and southwestern Asia widely cultivated for its white, yellow, pink, red, or orange flowers having multiple layers of petals')
# =============================================
# =============================================
# =============================================
# ('saxicolous', 'inhabiting or growing among rocks')
# =============================================
# =============================================
# ('schwarmerei', 'excessive sentiment')
# =============================================
# =============================================
# =============================================
# ('sibilance', 'a sibilant quality or sound')
# =============================================
# =============================================
# ('solecism', 'an ungrammatical combination of words in a sentence; also : a minor blunder in speech')
# =============================================
# ('solipsistic', 'of, relating to, or characterized by solipsism or extreme egocentricity')
# =============================================
# ('souchong', 'a tea made from the larger older leaves of the shoot')
# ('Lapsang souchong', 'a souchong tea having a pronounced smoky flavor and aroma')
# =============================================
# ('splanchnic', 'of or relating to the viscera : visceral')
# =============================================
# =============================================
# =============================================
# ('tabard', 'a short loose-fitting sleeveless or short-sleeved coat or cape: such as')
# =============================================
# =============================================
# ('theodicy', "defense of God's goodness and omnipotence in view of the existence of evil")
# =============================================
# =============================================
# =============================================
# ('tinnitus', 'a sensation of noise (such as a ringing or roaring) that is typically caused by a bodily condition (such as a disturbance of the auditory nerve or wax in the ear) and usually is of the subjective form which can only be heard by the one affected')
# =============================================
# ('toile', 'any of many plain or simple twill weave fabrics; especially : linen')
# ('toile de Jouy', 'an 18th century French scenic pattern usually printed on cotton, linen, or silk in one color on a light ground; broadly : a similar printed fabric')
# ("aide-toi, le ciel t'aidera:f", 'help yourself (and) heaven will help you : God helps those who help themselves')
# =============================================
# ('trepan:1', 'to use a trephine on (the skull)')
# ('trepan:4', 'entrap, lure')
# =============================================
# =============================================
# =============================================
# =============================================
# =============================================
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /var/folders/64/rp2jr10901n6vdvhsbn1fz7c0000gn/T/ipykernel_98116/1822908744.py in <module>
#      88 for w in words_without_meaning:
#      89     #print(df_all.loc[df_all['Word']==w,'Short Definition'].values[0])
# ---> 90     words.loc[words['Word']==w,'Meaning'] = df_all.loc[df_all['Word']==w,'Short Definition'].values
#      91 #return words, df_all
#      92
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexing.py in __setitem__(self, key, value)
#     721
#     722         iloc = self if self.name == "iloc" else self.obj.iloc
# --> 723         iloc._setitem_with_indexer(indexer, value, self.name)
#     724
#     725     def _validate_key(self, key, axis: int):
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexing.py in _setitem_with_indexer(self, indexer, value, name)
#    1730             self._setitem_with_indexer_split_path(indexer, value, name)
#    1731         else:
# -> 1732             self._setitem_single_block(indexer, value, name)
#    1733
#    1734     def _setitem_with_indexer_split_path(self, indexer, value, name: str):
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexing.py in _setitem_single_block(self, indexer, value, name)
#    1966
#    1967         # actually do the set
# -> 1968         self.obj._mgr = self.obj._mgr.setitem(indexer=indexer, value=value)
#    1969         self.obj._maybe_update_cacher(clear=True)
#    1970
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/internals/managers.py in setitem(self, indexer, value)
#     353
#     354     def setitem(self: T, indexer, value) -> T:
# --> 355         return self.apply("setitem", indexer=indexer, value=value)
#     356
#     357     def putmask(self, mask, new, align: bool = True):
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/internals/managers.py in apply(self, f, align_keys, ignore_failures, **kwargs)
#     325                     applied = b.apply(f, **kwargs)
#     326                 else:
# --> 327                     applied = getattr(b, f)(**kwargs)
#     328             except (TypeError, NotImplementedError):
#     329                 if not ignore_failures:
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/internals/blocks.py in setitem(self, indexer, value)
#     951             # setting a single element for each dim and with a rhs that could
#     952             #  be e.g. a list; see GH#6043
# --> 953             values[indexer] = value
#     954
#     955         elif exact_match and is_categorical_dtype(arr_value.dtype):
#
# ValueError: shape mismatch: value array of shape (0,)  could not be broadcast to indexing result of shape (1,)

# %%
df_all
# Out:
#                             Word  \
# 0                        alyssum
# 1                  sweet alyssum
# 2                      apodictic
# 3             Balearic Islands:g
# 4                        basenji
# 5                       carnauba
# 6                   carnauba wax
# 7                    composite:1
# 8                    composite:2
# 9                    composite:3
# 10            composite function
# 11                     corposant
# 12                     empennage
# 13                   fanfaronade
# 14                filiopietistic
# 15                 gerrymander:1
# 16                 gerrymander:2
# 17                      Gomorrah
# 18                    Gomorrah:g
# 19                   heldentenor
# 20                        hippie
# 21                    innominate
# 22             innominate artery
# 23               innominate bone
# 24               innominate vein
# 25        brachiocephalic artery
# 26          brachiocephalic vein
# 27               intussusception
# 28                        Latino
# 29                   Lubavitcher
# 30                   marquisette
# 31                   Merovingian
# 32                       Niger:g
# 33                      oximeter
# 34                pulse oximeter
# 35                       platina
# 36                    pursuivant
# 37                    ranunculus
# 38                    saxicolous
# 39                   schwarmerei
# 40                     sibilance
# 41                      solecism
# 42                   solipsistic
# 43                      souchong
# 44              Lapsang souchong
# 45                    splanchnic
# 46                        tabard
# 47                      theodicy
# 48                      tinnitus
# 49                         toile
# 50                 toile de Jouy
# 51  aide-toi, le ciel t'aidera:f
# 52                      trepan:1
# 53                      trepan:4
#
#                                      Short Definition
# 0   any of a genus (Alyssum) of Eurasian herbs of ...
# 1   a widely cultivated European herb (Lobularia m...
# 2   expressing or of the nature of necessary truth...
# 3   islands of eastern Spain in the western Medite...
# 4   any of a breed of small curly-tailed dogs of A...
# 5   a fan-leaved palm (Copernicia prunifera synony...
# 6   a hard brittle high-melting wax obtained from ...
# 7     made up of distinct parts or elements : such as
# 8                      something composite : compound
# 9       to make composite or into something composite
# 10  a function whose values are found from two giv...
# 11                                  saint elmo's fire
# 12                   the tail assembly of an aircraft
# 13                           empty boasting : bluster
# 14  of or relating to an often excessive veneratio...
# 15                the act or method of gerrymandering
# 16  to divide or arrange (a territorial unit) into...
# 17          a place notorious for vice and corruption
# 18  ancient city thought to be in the area now cov...
# 19  a tenor with a powerful, dramatic voice well s...
# 20  a usually young person who rejects the mores o...
# 21         having no name : unnamed; also : anonymous
# 22                             brachiocephalic artery
# 23                                           hip bone
# 24                               brachiocephalic vein
# 25  a short artery that arises from the arch of th...
# 26  either of two large veins that occur one on ea...
# 27    a drawing in of something from without: such as
# 28            a native or inhabitant of Latin America
# 29  a member of a Hasidic sect founded by Schneur ...
# 30  a sheer meshed fabric used for clothing, curta...
# 31  of or relating to the first Frankish dynasty r...
# 32  river 2600 miles (4184 kilometers) long in wes...
# 33  a noninvasive medical device for measuring con...
# 34  a noninvasive medical device that utilizes spe...
# 35                                           platinum
# 36  an officer of arms ranking below a herald but ...
# 37  any of a large genus (Ranunculus of the family...
# 38                  inhabiting or growing among rocks
# 39                                excessive sentiment
# 40                        a sibilant quality or sound
# 41  an ungrammatical combination of words in a sen...
# 42  of, relating to, or characterized by solipsism...
# 43  a tea made from the larger older leaves of the...
# 44  a souchong tea having a pronounced smoky flavo...
# 45           of or relating to the viscera : visceral
# 46  a short loose-fitting sleeveless or short-slee...
# 47  defense of God's goodness and omnipotence in v...
# 48  a sensation of noise (such as a ringing or roa...
# 49  any of many plain or simple twill weave fabric...
# 50  an 18th century French scenic pattern usually ...
# 51  help yourself (and) heaven will help you : God...
# 52                   to use a trephine on (the skull)
# 53                                       entrap, lure

# %%
df_all.fillna('Meaning', inplace=True)

# %%
#words_without_meaning
for w in words_without_meaning:
    print(w)
print(df_all[['Word','Short Definition']].values)
# Out:
# aborad
# alyssum
# anemochore
# apodictic
# Balearic
# basenji
# belonoid
# carnauba
# coadunate
# composite
# conticent
# corposant
# corticoline
# craquelure
# empennage
# engastrimythic
# fanfaronade
# filiopietistic
# gastrilegous
# gerrymander
# Gomorrah
# heldentenor
# hippie
# hyponychium
# innominate
# intussusception
# isapostolic
# Latino
# longicollous
# Lubavitcher
# lumbriciform
# marquisette
# Merovingian
# mithridatism
# mouchoir
# Nigerois
# obtenebrate
# oximeter
# parrhesia
# parvitude
# pignorate
# plasmoptysis
# platina
# pulsatance
# pursuivant
# Ranunculus
# roborant
# sarwan
# saxicolous
# scaphocephaly
# schwarmerei
# sciapodous
# Shaviana
# sibilance
# silicicolous
# solecism
# solipsistic
# souchong
# splanchnic
# stradiot
# syringeal
# tabard
# tanistry
# theodicy
# tichodrome
# timoneer
# tinnitus
# toile
# trepanation
# trimolecular
# vimineous
# vinegarroon
# vitrophyre
# xenial
# [['alyssum'
#   'any of a genus (Alyssum) of Eurasian herbs of the mustard family with small usually yellow racemose flowers —called also madwort']
#  ['sweet alyssum'
#   'a widely cultivated European herb (Lobularia maritima) of the mustard family having narrow leaves and clusters of small fragrant usually white or pink flowers']
#  ['apodictic'
#   'expressing or of the nature of necessary truth or absolute certainty']
#  ['Balearic Islands:g'
#   'islands of eastern Spain in the western Mediterranean Sea']
#  ['basenji'
#   'any of a breed of small curly-tailed dogs of African origin that do not bark']
#  ['carnauba'
#   'a fan-leaved palm (Copernicia prunifera synonym C. cerifera) of Brazil that has an edible root and yields a useful leaf fiber and carnauba wax']
#  ['carnauba wax'
#   'a hard brittle high-melting wax obtained from the leaves of the carnauba palm and used chiefly in polishes']
#  ['composite:1' 'made up of distinct parts or elements : such as']
#  ['composite:2' 'something composite : compound']
#  ['composite:3' 'to make composite or into something composite']
#  ['composite function'
#   'a function whose values are found from two given functions by applying one function to an independent variable and then applying the second function to the result and whose domain consists of those values of the independent variable for which the result yielded by the first function lies in the domain of the second']
#  ['corposant' "saint elmo's fire"]
#  ['empennage' 'the tail assembly of an aircraft']
#  ['fanfaronade' 'empty boasting : bluster']
#  ['filiopietistic'
#   'of or relating to an often excessive veneration of ancestors or tradition']
#  ['gerrymander:1' 'the act or method of gerrymandering']
#  ['gerrymander:2'
#   'to divide or arrange (a territorial unit) into election districts in a way that gives one political party an unfair advantage : to subject to gerrymandering']
#  ['Gomorrah' 'a place notorious for vice and corruption']
#  ['Gomorrah:g'
#   'ancient city thought to be in the area now covered by the southwestern part of the Dead Sea']
#  ['heldentenor'
#   'a tenor with a powerful, dramatic voice well suited to heroic roles (as in Wagnerian operas)']
#  ['hippie'
#   'a usually young person who rejects the mores of established society (as by dressing unconventionally or favoring communal living) and advocates a nonviolent ethic; broadly : a long-haired unconventionally dressed young person']
#  ['innominate' 'having no name : unnamed; also : anonymous']
#  ['innominate artery' 'brachiocephalic artery']
#  ['innominate bone' 'hip bone']
#  ['innominate vein' 'brachiocephalic vein']
#  ['brachiocephalic artery'
#   'a short artery that arises from the arch of the aorta and divides into the carotid and subclavian arteries of the right side —called also innominate artery']
#  ['brachiocephalic vein'
#   'either of two large veins that occur one on each side of the neck, receive blood from the head and neck, and unite to form the superior vena cava —called also innominate vein']
#  ['intussusception' 'a drawing in of something from without: such as']
#  ['Latino' 'a native or inhabitant of Latin America']
#  ['Lubavitcher'
#   'a member of a Hasidic sect founded by Schneur Zalman of Lyady in the late 18th century']
#  ['marquisette'
#   'a sheer meshed fabric used for clothing, curtains, and mosquito nets']
#  ['Merovingian'
#   'of or relating to the first Frankish dynasty reigning from about a.d. 500 to 751']
#  ['Niger:g'
#   'river 2600 miles (4184 kilometers) long in western Africa flowing north from the Fouta Djallon region in Guinea, northeast through Mali, and southeast through Niger, then forming the border between Niger and Benin, and finally flowing southeast then south through Nigeria and into the Gulf of Guinea']
#  ['oximeter'
#   'a noninvasive medical device for measuring continuously or intermittently the degree of oxygen saturation of circulating blood or a localized region of tissue; especially : pulse oximeter']
#  ['pulse oximeter'
#   'a noninvasive medical device that utilizes spectrophotometry to measure the oxygen saturation of circulating arterial blood in an individual by determining the percentage of oxygenated hemoglobin pulsating through a network of blood capillaries by way of a sensor attached typically to a finger, toe, or earlobe']
#  ['platina' 'platinum']
#  ['pursuivant'
#   'an officer of arms ranking below a herald but having similar duties']
#  ['ranunculus'
#   'any of a large genus (Ranunculus of the family Ranunculaceae, the buttercup family) of chiefly perennial herbaceous plants with tuberous or fibrous roots and typically yellow, five-petaled, cup-shaped flowers and including one (R. asiaticus) of southeastern Europe and southwestern Asia widely cultivated for its white, yellow, pink, red, or orange flowers having multiple layers of petals']
#  ['saxicolous' 'inhabiting or growing among rocks']
#  ['schwarmerei' 'excessive sentiment']
#  ['sibilance' 'a sibilant quality or sound']
#  ['solecism'
#   'an ungrammatical combination of words in a sentence; also : a minor blunder in speech']
#  ['solipsistic'
#   'of, relating to, or characterized by solipsism or extreme egocentricity']
#  ['souchong' 'a tea made from the larger older leaves of the shoot']
#  ['Lapsang souchong'
#   'a souchong tea having a pronounced smoky flavor and aroma']
#  ['splanchnic' 'of or relating to the viscera : visceral']
#  ['tabard'
#   'a short loose-fitting sleeveless or short-sleeved coat or cape: such as']
#  ['theodicy'
#   "defense of God's goodness and omnipotence in view of the existence of evil"]
#  ['tinnitus'
#   'a sensation of noise (such as a ringing or roaring) that is typically caused by a bodily condition (such as a disturbance of the auditory nerve or wax in the ear) and usually is of the subjective form which can only be heard by the one affected']
#  ['toile'
#   'any of many plain or simple twill weave fabrics; especially : linen']
#  ['toile de Jouy'
#   'an 18th century French scenic pattern usually printed on cotton, linen, or silk in one color on a light ground; broadly : a similar printed fabric']
#  ["aide-toi, le ciel t'aidera:f"
#   'help yourself (and) heaven will help you : God helps those who help themselves']
#  ['trepan:1' 'to use a trephine on (the skull)']
#  ['trepan:4' 'entrap, lure']]

# %%
#df1.reset_index(inplace=True)
df_all.loc[4:6]
# Out:
#            Word                                   Short Definition
# 4       basenji  any of a breed of small curly-tailed dogs of A...
# 5      carnauba  a fan-leaved palm (Copernicia prunifera synony...
# 6  carnauba wax  a hard brittle high-melting wax obtained from ...

# %%
len(df_all)
# Out:
# 54

# %%
'''for w in words_without_meaning:
    #print(df_all.loc[df_all['Word']==w,'Short Definition'].values[0])
    words.loc[words['Word']==w,'Meaning'] = df_all.loc[df_all['Word']==w,'Short Definition'].values[0]'''
# Out:
# "for w in words_without_meaning:\n    #print(df_all.loc[df_all['Word']==w,'Short Definition'].values[0])\n    words.loc[words['Word']==w,'Meaning'] = df_all.loc[df_all['Word']==w,'Short Definition'].values[0]"

# %%
#df_all['Short Definition'].rename('Meaning', inplace=True)

# %%
#words = get_word_meaning_mw(df1, respE)
df_all.rename(columns={'Short Definition':'Meaning'}, inplace=True)

# %%
df_all
# Out:
#                             Word  \
# 0                        alyssum
# 1                  sweet alyssum
# 2                      apodictic
# 3             Balearic Islands:g
# 4                        basenji
# 5                       carnauba
# 6                   carnauba wax
# 7                    composite:1
# 8                    composite:2
# 9                    composite:3
# 10            composite function
# 11                     corposant
# 12                     empennage
# 13                   fanfaronade
# 14                filiopietistic
# 15                 gerrymander:1
# 16                 gerrymander:2
# 17                      Gomorrah
# 18                    Gomorrah:g
# 19                   heldentenor
# 20                        hippie
# 21                    innominate
# 22             innominate artery
# 23               innominate bone
# 24               innominate vein
# 25        brachiocephalic artery
# 26          brachiocephalic vein
# 27               intussusception
# 28                        Latino
# 29                   Lubavitcher
# 30                   marquisette
# 31                   Merovingian
# 32                       Niger:g
# 33                      oximeter
# 34                pulse oximeter
# 35                       platina
# 36                    pursuivant
# 37                    ranunculus
# 38                    saxicolous
# 39                   schwarmerei
# 40                     sibilance
# 41                      solecism
# 42                   solipsistic
# 43                      souchong
# 44              Lapsang souchong
# 45                    splanchnic
# 46                        tabard
# 47                      theodicy
# 48                      tinnitus
# 49                         toile
# 50                 toile de Jouy
# 51  aide-toi, le ciel t'aidera:f
# 52                      trepan:1
# 53                      trepan:4
#
#                                               Meaning
# 0   any of a genus (Alyssum) of Eurasian herbs of ...
# 1   a widely cultivated European herb (Lobularia m...
# 2   expressing or of the nature of necessary truth...
# 3   islands of eastern Spain in the western Medite...
# 4   any of a breed of small curly-tailed dogs of A...
# 5   a fan-leaved palm (Copernicia prunifera synony...
# 6   a hard brittle high-melting wax obtained from ...
# 7     made up of distinct parts or elements : such as
# 8                      something composite : compound
# 9       to make composite or into something composite
# 10  a function whose values are found from two giv...
# 11                                  saint elmo's fire
# 12                   the tail assembly of an aircraft
# 13                           empty boasting : bluster
# 14  of or relating to an often excessive veneratio...
# 15                the act or method of gerrymandering
# 16  to divide or arrange (a territorial unit) into...
# 17          a place notorious for vice and corruption
# 18  ancient city thought to be in the area now cov...
# 19  a tenor with a powerful, dramatic voice well s...
# 20  a usually young person who rejects the mores o...
# 21         having no name : unnamed; also : anonymous
# 22                             brachiocephalic artery
# 23                                           hip bone
# 24                               brachiocephalic vein
# 25  a short artery that arises from the arch of th...
# 26  either of two large veins that occur one on ea...
# 27    a drawing in of something from without: such as
# 28            a native or inhabitant of Latin America
# 29  a member of a Hasidic sect founded by Schneur ...
# 30  a sheer meshed fabric used for clothing, curta...
# 31  of or relating to the first Frankish dynasty r...
# 32  river 2600 miles (4184 kilometers) long in wes...
# 33  a noninvasive medical device for measuring con...
# 34  a noninvasive medical device that utilizes spe...
# 35                                           platinum
# 36  an officer of arms ranking below a herald but ...
# 37  any of a large genus (Ranunculus of the family...
# 38                  inhabiting or growing among rocks
# 39                                excessive sentiment
# 40                        a sibilant quality or sound
# 41  an ungrammatical combination of words in a sen...
# 42  of, relating to, or characterized by solipsism...
# 43  a tea made from the larger older leaves of the...
# 44  a souchong tea having a pronounced smoky flavo...
# 45           of or relating to the viscera : visceral
# 46  a short loose-fitting sleeveless or short-slee...
# 47  defense of God's goodness and omnipotence in v...
# 48  a sensation of noise (such as a ringing or roa...
# 49  any of many plain or simple twill weave fabric...
# 50  an 18th century French scenic pattern usually ...
# 51  help yourself (and) heaven will help you : God...
# 52                   to use a trephine on (the skull)
# 53                                       entrap, lure

# %%
df_merged = pd.merge(left=df1['Word'], right=df_all, how='outer', on='Word')

# %%
writer = pd.ExcelWriter('paideia_words_on_1998_edition_not_on_2004-2006_edit.xlsx', engine='xlsxwriter')
for i in range(0,500,500):
    df_merged.iloc[i:i+500,:].to_excel(writer, sheet_name=str(i+1)+'-'+ str(i+500), index=False)
writer.save()
