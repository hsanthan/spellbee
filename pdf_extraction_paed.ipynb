# %%
import textract
import PyPDF2
import numpy as np
import pandas as pd
from tika import parser
import tabula
import re
import requests
import os

# %%
keyid_inter = '9cfbf9ed-b6c0-4ab1-9762-9383fb15a5de'
keyid_col = '1c635859-2b31-41b2-9802-572347452d30'
keyid_med = '83de8977-c9be-4663-ab6a-0fb6b70641e2'

# %%
pdf = '/Users/hema/Downloads/SpellBee/paideia-1998.pdf'

# %% [markdown]
# pypdf

# %%
pdf_file = open(pdf, 'rb')
pdf_reader_obj = PyPDF2.PdfFileReader(pdf_file)
pdf_reader_obj.getNumPages()
# Out:
# 15

# %%
pg = pdf_reader_obj.getPage(5)
pg.extractText().split('\n')
# Out:
# [' ',
#  'TheSpellingBeeChamp.wordpress.com',
#  ' ',
#  'PAIDEIA ',
#  '1998',
#  ' ',
#  'extemporaneous',
#  ' ',
#  'extortion',
#  ' ',
#  'extradition',
#  ' ',
#  'extraneous',
#  ' ',
#  'extravaganza',
#  ' ',
#  'eyeball',
#  ' ',
#  'eyelid',
#  ' ',
#  'facial',
#  ' ',
#  'failure',
#  ' ',
#  'faineant',
#  ' ',
#  'faithful',
#  ' ',
#  'faja',
#  ' ',
#  'fajitas',
#  ' ',
#  'falconry',
#  ' ',
#  'fallow',
#  ' ',
#  'famine',
#  ' ',
#  'fancily',
#  ' ',
#  'fandangle',
#  ' ',
#  'fanfaronade',
#  ' ',
#  'fantoccini',
#  ' ',
#  'fasciculus',
#  ' ',
#  'fascism',
#  ' ',
#  'fasten',
#  ' ',
#  'fastigium',
#  ' ',
#  'fatigues',
#  ' ',
#  'fauna',
#  ' ',
#  'fealty',
#  ' ',
#  'febricula',
#  ' ',
#  'feis',
#  ' ',
#  'feliform',
#  ' ',
#  'fellow',
#  ' ',
#  'felony',
#  ' ',
#  'femur',
#  ' ',
#  'Fennoscandian',
#  ' ',
#  'fermata',
#  ' ',
#  'ferret',
#  ' ',
#  'ferric',
#  ' ',
#  'festoon',
#  ' ',
#  'fetter',
#  ' ',
#  'feudal',
#  ' ',
#  'few',
#  ' ',
#  'fianchetto',
#  ' ',
#  'fiddlehead',
#  ' ',
#  'fidgeting',
#  ' ',
#  'fielder',
#  ' ',
#  'fiercest',
#  ' ',
#  'fiery',
#  ' ',
#  'fiesta',
#  ' ',
#  'fifth',
#  ' ',
#  'figurine',
#  ' ',
#  'filamentary',
#  ' ',
#  'filibuster',
#  ' ',
#  'filiopietistic',
#  ' ',
#  'filmography',
#  ' ',
#  'filmscript',
#  ' ',
#  'finery',
#  ' ',
#  'finial',
#  ' ',
#  'firepower',
#  ' ',
#  'firkin',
#  ' ',
#  'fishgig',
#  ' ',
#  'fisticuffs',
#  ' ',
#  'fistula',
#  ' ',
#  'fixation',
#  ' ',
#  'flaccid',
#  ' ',
#  'flagellate',
#  ' ',
#  'flambeau',
#  ' ',
#  'flamingo',
#  ' ',
#  'flammeous',
#  ' ',
#  'flange',
#  ' ',
#  'flashback',
#  ' ',
#  'flautino',
#  ' ',
#  'fleabane',
#  ' ',
#  'fleer',
#  ' ',
#  'fleet',
#  ' ',
#  'fletching',
#  ' ',
#  'flimflam',
#  ' ',
#  'Flinders',
#  ' ',
#  'floccillation',
#  ' ',
#  'flock',
#  ' ',
#  'floodlight',
#  ' ',
#  'flora',
#  ' ',
#  'floreted',
#  ' ',
#  'floruit',
#  ' ',
#  'floss',
#  ' ',
#  'flotilla',
#  ' ',
#  'flotsam',
#  ' ',
#  'flouncing',
#  ' ',
#  'flounder',
#  ' ',
#  'floweret',
#  ' ',
#  'flunk',
#  ' ',
#  'fluoride',
#  ' ',
#  'fluster',
#  ' ',
#  'flypaper',
#  ' ',
#  'foil',
#  ' ',
#  'foliage',
#  ' ',
#  'foliation',
#  ' ',
#  'folio',
#  ' ',
#  'folksiness',
#  ' ',
#  'folletto',
#  ' ',
#  'follicle',
#  ' ',
#  'Fomorian',
#  ' ',
#  'foolocracy',
#  ' ',
#  'footing',
#  ' ',
#  'forage',
#  ' ',
#  'foramen',
#  ' ',
#  'foreground',
#  ' ',
#  'forensics',
#  ' ',
#  'forestall',
#  ' ',
#  'forestry',
#  ' ',
#  'forgery',
#  ' ',
#  'formally',
#  ' ',
#  'former',
#  ' ',
#  'formula',
#  ' ',
#  'forsooth',
#  ' ',
#  'forsythia',
#  ' ',
#  'fortification',
#  ' ',
#  'fortnight',
#  ' ',
#  'fortress',
#  ' ',
#  'fourscore',
#  ' ',
#  'fourteen',
#  ' ',
#  'foxing',
#  ' ',
#  'frat',
#  ' ',
#  'fraud',
#  ' ',
#  'frazzle',
#  ' ',
#  'freckle',
#  ' ',
#  'fresh',
#  ' ',
#  'friar',
#  ' ',
#  'fricassee',
#  ' ',
#  'friction',
#  ' ',
#  'frieze',
#  ' ',
#  'frogged',
#  ' ',
#  'frolicsome',
#  ' ',
#  'frondescence',
#  ' ',
#  'fronds',
#  ' ',
#  'frontispiece',
#  ' ',
#  'fronton',
#  ' ',
#  'froufrou',
#  ' ',
#  'fughetta',
#  ' ',
#  'fuliginous',
#  ' ',
#  'fulsomely',
#  ' ',
#  'fulvous',
#  ' ',
#  'funambulist',
#  ' ',
#  'funereal',
#  ' ',
#  'funipendulous',
#  ' ',
#  'furbelow',
#  ' ',
#  'furlough',
#  ' ',
#  'furuncle',
#  ' ',
#  'fusillade',
#  ' ',
#  'fusilli',
#  ' ',
#  'fusion',
#  ' ',
#  'fustanella',
#  ' ',
#  'futurity',
#  ' ',
#  'gadroon',
#  ' ',
#  'gaffer',
#  ' ',
#  'gaggle',
#  ' ',
#  'gagtooth',
#  ' ',
#  'Galahad',
#  ' ',
#  'gallery',
#  ' ',
#  'Gallinazo',
#  ' ',
#  'gallows',
#  ' ',
#  'galvanic',
#  ' ',
#  'gambrel',
#  ' ',
#  'gammelost',
#  ' ',
#  'ganglion',
#  ' ',
#  'garderobe',
#  ' ',
#  'gargantuan',
#  ' ',
#  'garland',
#  ' ',
#  'garnish',
#  ' ',
#  'garrison',
#  ' ',
#  'garter',
#  ' ',
#  'garth',
#  ' ',
#  'gaseous',
#  ' ',
#  'gastric',
#  ' ',
#  'gastrilegous',
#  ' ',
#  'gastrocnemius',
#  ' ',
#  'gastroenterology',
#  ' ',
#  'gaufrette',
#  ' ',
#  'gazpacho',
#  ' ',
#  'gemmary',
#  ' ',
#  'gendarme',
#  ' ',
#  'gender',
#  ' ',
#  'genealogy',
#  ' ',
#  'general',
#  ' ',
#  'generate',
#  ' ',
#  'genius',
#  ' ',
#  'genocide',
#  ' ',
#  'genre',
#  ' ',
#  'genteel',
#  ' ',
#  'gentle',
#  ' ',
#  'gentry',
#  ' ',
#  'genuflect',
#  ' ',
#  'genus',
#  ' ',
#  'geochrony',
#  ' ',
#  'geranium',
#  ' ',
#  'geriatrics',
#  ' ',
#  'germane',
#  ' ',
#  'germinate',
#  ' ',
#  'gerontology',
#  ' ',
#  'gerrymander',
#  ' ',
#  'gestalt',
#  ' ',
#  'gestapo',
#  ' ',
#  'giaour',
#  ' ',
#  'gibbet',
#  ' ',
#  'gigot',
#  ' ',
#  'gilded',
#  ' ',
#  'ginglymus',
#  ' ',
#  'gird',
#  ' ',
#  'glaucous',
#  ' ',
#  'glima',
#  ' ',
#  'glimpse',
#  ' ',
#  'glistened',
#  ' ',
#  'glittering',
#  ' ',
#  'glossal',
#  ' ',
#  'glossolalia',
#  ' ',
#  'glottology',
#  ' ',
#  'glucocorticoid',
#  ' ',
#  'glutinous',
#  ' ',
#  'glycerol',
#  ' ',
#  'glycogen',
#  ' ',
#  'gnats',
#  ' ',
#  'gnomic',
#  ' ',
#  'gnosis',
#  ' ',
#  'goal',
#  ' ',
#  'golem',
#  ' ',
#  '']

# %% [markdown]
# #tabula

# %%
df = tabula.read_pdf(pdf)
# Out:
# 'pages' argument isn't specified.Will extract only from page 1 by default.

# %%
df
# Out:
# [                           Unnamed: 0   PAIDEIA 1998      Unnamed: 1
#  0                                 NaN            NaN             NaN
#  1   TheSpellingBeeChamp.wordpress.com            NaN             NaN
#  2                    abalone affinity     amphibious            aqua
#  3                   abdicate afflatus     amphoteric         aqueous
#  4                  abduction agalloch     amygdaline        aquiline
#  5                      ablution agape       anabasis       arabesque
#  6                      abnormal agate    anachronism       arachnoid
#  7                        aborad aggie       anaglyph  arachnophagous
#  8            aboriginally agglutinate      anamnesis   arboriculture
#  9                absolution aggregate        anarchy         arbutus
#  10                abstention agnostic    anastomosis         arcaded
#  11                     academe agonal       anathema          arcane
#  12               academia agrarianism       ancestor         archaic
#  13               academician agronomy        anchovy       archangel
#  14                    acanthus ahimsa        ancient         archery
#  15                   accipiter ahorse        ancilla    architecture
#  16            acclamation aiguillette        andante      architrave
#  17              accommodation aileron  anemobiagraph       archizoic
#  18                 accomplice Ailurus     anemochore          argent
#  19                 accretionary aioli      anemology        argonaut
#  20                  accumulate aition       anglaise         arietta
#  21                   acedia alabaster          angst          armada
#  22                 acetabulum alchemy      anhydrous       armadillo
#  23                      acetic alcove  animadversion       armaments
#  24                   acetone aldehyde        animism        armature
#  25             acetylcholine alderman        anionic         armiger
#  26                acharya aldosterone         anneal       armistice
#  27                  Achillean alembic     annexation         arrears
#  28             achondroplasia alfalfa    anniversary        arrestee
#  29                      acicula algid        annulet  arrondissement
#  30                      acolyte alias           anon         arsenic
#  31                    acoustics alibi      anschluss           arson
#  32                acrocyanosis alison        Antaean          artery
#  33                  acrolect alkaline     antagonist       Arthurian
#  34                    actinide alkane           ante      articulate
#  35                   adder allotropic     antebellum       artillery
#  36                    adherend allure     antecessor   aryepiglottic
#  37                       adios alpaca   antediluvian            aryl
#  38              adjournment alpenglow       antenati       ascension
#  39             adminicle alstroemeria     anticlimax        asphodel
#  40                admonish altarpiece    antiquarian           aspic
#  41                    adobe altiplano      antiquity   assassination
#  42                     adobo alveolar       aoristic         assault
#  43                adolescence alyssum          aorta        assemble
#  44                     Adonis amalgam        aparejo      assignment
#  45                   adonize amandine        aphasia          assisi
#  46                   adustiosis amass      apodictic        asterisk
#  47                adversary amaurosis     Apollonian      astrologer
#  48                aebleskive ambrosia       apostate      asynchrony
#  49                 aerodromics ambush        apostle           atlas
#  50             aerodynamic amercement     apotheosis       atmogenic
#  51                aerolithology amigo    apparatchik     atmospheric
#  52                   aeronautic amine  apparentement        atrament
#  53                   aerosol ammoniac    appeasement          atrium
#  54             Aesculapian ammunition      appellate       atrocious
#  55                      Aesir amnesty     appetitost         atrophy
#  56                   Aesopian amorino      appliquer         attaboy
#  57                affidavit amorphous      apprehend      attachable]

# %% [markdown]
# tika /textract

# %%
txt = parser.from_file(pdf)

# %%
text = txt['content'].split('\n\n')
text
# Out:
# ['',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '\nPaideia 1998',
#  '\n \nTheSpellingBeeChamp.wordpress.com ',
#  'PAIDEIA 1998 ',
#  'abalone ',
#  'abdicate ',
#  'abduction ',
#  'ablution ',
#  'abnormal ',
#  'aborad ',
#  'aboriginally ',
#  'absolution ',
#  'abstention ',
#  'academe ',
#  'academia ',
#  'academician ',
#  'acanthus ',
#  'accipiter ',
#  'acclamation ',
#  'accommodation ',
#  'accomplice ',
#  'accretionary ',
#  'accumulate ',
#  'acedia ',
#  'acetabulum ',
#  'acetic ',
#  'acetone ',
#  'acetylcholine ',
#  'acharya ',
#  'Achillean ',
#  'achondroplasia ',
#  'acicula ',
#  'acolyte ',
#  'acoustics ',
#  'acrocyanosis ',
#  'acrolect ',
#  'actinide ',
#  'adder ',
#  'adherend ',
#  'adios ',
#  'adjournment ',
#  'adminicle ',
#  'admonish ',
#  'adobe ',
#  'adobo ',
#  'adolescence ',
#  'Adonis ',
#  'adonize ',
#  'adustiosis ',
#  'adversary ',
#  'aebleskive ',
#  'aerodromics ',
#  'aerodynamic ',
#  'aerolithology ',
#  'aeronautic ',
#  'aerosol ',
#  'Aesculapian ',
#  'Aesir ',
#  'Aesopian ',
#  'affidavit ',
#  'affinity ',
#  'afflatus ',
#  'agalloch ',
#  'agape ',
#  'agate ',
#  'aggie ',
#  'agglutinate ',
#  'aggregate ',
#  'agnostic ',
#  'agonal ',
#  'agrarianism ',
#  'agronomy ',
#  'ahimsa ',
#  'ahorse ',
#  'aiguillette ',
#  'aileron ',
#  'Ailurus ',
#  'aioli ',
#  'aition ',
#  'alabaster ',
#  'alchemy ',
#  'alcove ',
#  'aldehyde ',
#  'alderman ',
#  'aldosterone ',
#  'alembic ',
#  'alfalfa ',
#  'algid ',
#  'alias ',
#  'alibi ',
#  'alison ',
#  'alkaline ',
#  'alkane ',
#  'allotropic ',
#  'allure ',
#  'alpaca ',
#  'alpenglow ',
#  'alstroemeria ',
#  'altarpiece ',
#  'altiplano ',
#  'alveolar ',
#  'alyssum ',
#  'amalgam ',
#  'amandine ',
#  'amass ',
#  'amaurosis ',
#  'ambrosia ',
#  'ambush ',
#  'amercement ',
#  'amigo ',
#  'amine ',
#  'ammoniac ',
#  'ammunition ',
#  'amnesty ',
#  'amorino ',
#  'amorphous ',
#  'amphibious ',
#  'amphoteric ',
#  'amygdaline ',
#  'anabasis ',
#  'anachronism ',
#  'anaglyph ',
#  'anamnesis ',
#  'anarchy ',
#  'anastomosis ',
#  'anathema ',
#  'ancestor ',
#  'anchovy ',
#  'ancient ',
#  'ancilla ',
#  'andante ',
#  'anemobiagraph ',
#  'anemochore ',
#  'anemology ',
#  'anglaise ',
#  'angst ',
#  'anhydrous ',
#  'animadversion ',
#  'animism ',
#  'anionic ',
#  'anneal ',
#  'annexation ',
#  'anniversary ',
#  'annulet ',
#  'anon ',
#  'anschluss ',
#  'Antaean ',
#  'antagonist ',
#  'ante ',
#  'antebellum ',
#  'antecessor ',
#  'antediluvian ',
#  'antenati ',
#  'anticlimax ',
#  'antiquarian ',
#  'antiquity ',
#  'aoristic ',
#  'aorta ',
#  'aparejo ',
#  'aphasia ',
#  'apodictic ',
#  'Apollonian ',
#  'apostate ',
#  'apostle ',
#  'apotheosis ',
#  'apparatchik ',
#  'apparentement ',
#  'appeasement ',
#  'appellate ',
#  'appetitost ',
#  'appliquer ',
#  'apprehend ',
#  'aqua ',
#  'aqueous ',
#  'aquiline ',
#  'arabesque ',
#  'arachnoid ',
#  'arachnophagous ',
#  'arboriculture ',
#  'arbutus ',
#  'arcaded ',
#  'arcane ',
#  'archaic ',
#  'archangel ',
#  'archery ',
#  'architecture ',
#  'architrave ',
#  'archizoic ',
#  'argent ',
#  'argonaut ',
#  'arietta ',
#  'armada ',
#  'armadillo ',
#  'armaments ',
#  'armature ',
#  'armiger ',
#  'armistice ',
#  'arrears ',
#  'arrestee ',
#  'arrondissement ',
#  'arsenic ',
#  'arson ',
#  'artery ',
#  'Arthurian ',
#  'articulate ',
#  'artillery ',
#  'aryepiglottic ',
#  'aryl ',
#  'ascension ',
#  'asphodel ',
#  'aspic ',
#  'assassination ',
#  'assault ',
#  'assemble ',
#  'assignment ',
#  'assisi ',
#  'asterisk ',
#  'astrologer ',
#  'asynchrony ',
#  'atlas ',
#  'atmogenic ',
#  'atmospheric ',
#  'atrament ',
#  'atrium ',
#  'atrocious ',
#  'atrophy ',
#  'attaboy ',
#  'attachable ',
#  '',
#  ' \nTheSpellingBeeChamp.wordpress.com ',
#  'PAIDEIA 1998 ',
#  'attraction ',
#  'auburn ',
#  'audit ',
#  'audition ',
#  'Augean ',
#  'auk ',
#  'aureate ',
#  'aureole ',
#  'auricle ',
#  'auteur ',
#  'autonomous ',
#  'autopsy ',
#  'autumnal ',
#  'avalanche ',
#  'avgolemono ',
#  'awkward ',
#  'axel ',
#  'axiom ',
#  'axletree ',
#  'ayatollah ',
#  'ayuntamiento ',
#  'azalea ',
#  'Aztec ',
#  'azure ',
#  'babushka ',
#  'backgammon ',
#  'badminton ',
#  'bagatelle ',
#  'baignoire ',
#  'bailey ',
#  'baldmoney ',
#  'Balearic ',
#  'ballabile ',
#  'ballast ',
#  'ballistic ',
#  'ballistics ',
#  'ballot ',
#  'ballotage ',
#  'banderilla ',
#  'banditry ',
#  'banquette ',
#  'barbellate ',
#  'barbican ',
#  'bardiglio ',
#  'barding ',
#  'barefoot ',
#  'barnstorm ',
#  'baronet ',
#  'baroque ',
#  'barracks ',
#  'barrage ',
#  'barricade ',
#  'barrio ',
#  'bartizan ',
#  'bascule ',
#  'basenji ',
#  'basilisk ',
#  'baste ',
#  'bastion ',
#  'battalion ',
#  'batten ',
#  'battlement ',
#  'bauble ',
#  'bawcock ',
#  'bawl ',
#  'bayonet ',
#  'bazooka ',
#  'beaker ',
#  'bedchamber ',
#  'bedeck ',
#  'bedizen ',
#  'beeline ',
#  'beige ',
#  'bellicose ',
#  'belonoid ',
#  'benevolence ',
#  'benignant ',
#  'benjamin ',
#  'benumbed ',
#  'bereavement ',
#  'bergschrund ',
#  'berserk ',
#  'bethel ',
#  'bezique ',
#  'bibelot ',
#  'bibliotherapy ',
#  'bibliotics ',
#  'bicameral ',
#  'bicaudate ',
#  'biennium ',
#  'bigamy ',
#  'bijou ',
#  'bilberry ',
#  'bilge ',
#  'bilirubin ',
#  'billiards ',
#  'billycan ',
#  'binary ',
#  'biotic ',
#  'birdlime ',
#  'bisect ',
#  'bivouac ',
#  'bizonal ',
#  'blabber ',
#  'blackmail ',
#  'blanch ',
#  'blancmange ',
#  'blanquette ',
#  'blanquillo ',
#  'blasphemous ',
#  'blasphemy ',
#  'blatherskite ',
#  'blazon ',
#  'blepharal ',
#  'blindfold ',
#  'blintze ',
#  'blitz ',
#  'blitzkrieg ',
#  'bloc ',
#  'blockade ',
#  'blockhead ',
#  'blooper ',
#  'blunderbuss ',
#  'boatload ',
#  'bocaccio ',
#  'bocage ',
#  'bodega ',
#  'bolivar ',
#  'bollard ',
#  'bolshevize ',
#  'bolster ',
#  'bolt ',
#  'bombardment ',
#  'bonanza ',
#  'bondsman ',
#  'boniest ',
#  'Bonnaz ',
#  'boon ',
#  'bootlegger ',
#  'borane ',
#  'boric ',
#  'borough ',
#  'borsholder ',
#  'bouillon ',
#  'bovine ',
#  'bowgrace ',
#  'bowline ',
#  'Boyg ',
#  'bracken ',
#  'bradytely ',
#  'brassy ',
#  'breaker ',
#  'breastplate ',
#  'bretelle ',
#  'brevet ',
#  'breviary ',
#  'bribery ',
#  'bridegroom ',
#  'brigadier ',
#  'brigand ',
#  'brink ',
#  'brisque ',
#  'broadcast ',
#  'brocade ',
#  'brochette ',
#  'brogan ',
#  'broguing ',
#  'bromeliad ',
#  'bronchial ',
#  'bronze ',
#  'brooklime ',
#  'brotherliness ',
#  'browbeat ',
#  'brownstone ',
#  'brunneous ',
#  'buccal ',
#  'buccinators ',
#  'buff ',
#  'buffoon ',
#  'bulla ',
#  'bulletin ',
#  'bunch ',
#  'bungle ',
#  'Bunraku ',
#  'bunt ',
#  'Bunyanesque ',
#  'bureaucracy ',
#  'Burgher ',
#  'burglary ',
#  'burgoo ',
#  'burgrave ',
#  'burgundy ',
#  'burro ',
#  'buttony ',
#  'buttress ',
#  'byrnie ',
#  'byzantine ',
#  'cabana ',
#  'cabecera ',
#  'cabochon ',
#  'cabriolet ',
#  'cabrito ',
#  'cadences ',
#  'cadet ',
#  'Caesar ',
#  'cahier ',
#  'calcaneus ',
#  'calcitonin ',
#  'caldera ',
#  'Calinago ',
#  'calliope ',
#  'calorimetric ',
#  'calypso ',
#  'calzone ',
#  'camarilla ',
#  'Camelot ',
#  'cameo ',
#  'camisa ',
#  'camouflage ',
#  'campaign ',
#  'campanile ',
#  'campesino ',
#  'Canaan ',
#  'canary ',
#  '',
#  ' \nTheSpellingBeeChamp.wordpress.com ',
#  'PAIDEIA 1998 ',
#  'cannoli ',
#  'canoeist ',
#  'canopy ',
#  'cantatrice ',
#  'cantina ',
#  'cantle ',
#  'canton ',
#  'cantonment ',
#  'cantor ',
#  'caparison ',
#  'capeador ',
#  'caper ',
#  'capillary ',
#  'capitalist ',
#  'capitatim ',
#  'capitulation ',
#  'cappelletti ',
#  'capretto ',
#  'capriccio ',
#  'capsule ',
#  'caramelize ',
#  'caravel ',
#  'carbide ',
#  'carbohydrates ',
#  'carbonate ',
#  'carcinogenic ',
#  'cardiac ',
#  'cardinal ',
#  'careworn ',
#  'cargador ',
#  'carmine ',
#  'carnauba ',
#  'carnival ',
#  'carotid ',
#  'carp ',
#  'carpaccio ',
#  'carrion ',
#  'carstone ',
#  'caruncle ',
#  'carving ',
#  'cascabel ',
#  'casement ',
#  'cask ',
#  'Cassandra ',
#  'castanets ',
#  'caste ',
#  'castellan ',
#  'castrametation ',
#  'casuistry ',
#  'cataclastic ',
#  'catacombs ',
#  'catalineta ',
#  'catalytic ',
#  'cataphract ',
#  'catastasis ',
#  'catastrophe ',
#  'cate ',
#  'catenate ',
#  'catholic ',
#  'cationic ',
#  'catullian ',
#  'caucus ',
#  'caudillo ',
#  'cavalletti ',
#  'cavalry ',
#  'cedilla ',
#  'celestial ',
#  'celluloid ',
#  'census ',
#  'centiday ',
#  'centralization ',
#  'centripetal ',
#  'centrist ',
#  'centurion ',
#  'Cerberean ',
#  'cerebellar ',
#  'cesspool ',
#  'cetology ',
#  'chaffinch ',
#  'chamberlain ',
#  'champagne ',
#  'chancellor ',
#  'chandelier ',
#  'changa ',
#  'chapel ',
#  'charango ',
#  'charcuterie ',
#  'charismatic ',
#  'charter ',
#  'charterhouse ',
#  'Charybdis ',
#  'chassepot ',
#  'chatelaine ',
#  'chayote ',
#  'checkoff ',
#  'chelate ',
#  'chenille ',
#  'chernozem ',
#  'chessman ',
#  'chesstree ',
#  'chevesaile ',
#  'chevrette ',
#  'chiaroscurist ',
#  'chicanery ',
#  'Chicano ',
#  'chichi ',
#  'chickling ',
#  'chiffonade ',
#  'chihuahua ',
#  'chimerical ',
#  'Chinarra ',
#  'chinoiserie ',
#  'chionablepsia ',
#  'chiral ',
#  'chirography ',
#  'chisel ',
#  'chistera ',
#  'chivalry ',
#  'chloasma ',
#  'chlorine ',
#  'chloroform ',
#  'chlorosis ',
#  'choker ',
#  'cholesterol ',
#  'cholinesterase ',
#  'choucroute ',
#  'chouette ',
#  'chowder ',
#  'chrestomathy ',
#  'chroma ',
#  'chromatosis ',
#  'chromic ',
#  'chromometer ',
#  'chromosome ',
#  'chronal ',
#  'chronic ',
#  'chronicles ',
#  'chronologize ',
#  'chrysalis ',
#  'chrysanthemum ',
#  'chrysochlorous ',
#  'churn ',
#  'churrasco ',
#  'churrigueresque ',
#  'chutney ',
#  'chyle ',
#  'chymotrypsin ',
#  'cilantro ',
#  'Cimmerian ',
#  'cincture ',
#  'cinematheque ',
#  'cinephile ',
#  'cinereal ',
#  'cinque ',
#  'circuit ',
#  'circulate ',
#  'circumstantial ',
#  'cirrhosis ',
#  'CIS ',
#  'citadel ',
#  'civics ',
#  'clambake ',
#  'clandestinely ',
#  'clavicle ',
#  'cleave ',
#  'clematis ',
#  'clergy ',
#  'clerisy ',
#  'clingy ',
#  'clinquant ',
#  'cloture ',
#  'clumsy ',
#  'cluster ',
#  'coadunate ',
#  'coagulate ',
#  'coalesce ',
#  'coalition ',
#  'coalmouse ',
#  'cobweb ',
#  'coccygeal ',
#  'cochlear ',
#  'codicil ',
#  'coexistence ',
#  'cofeature ',
#  'cognate ',
#  'coherent ',
#  'coinage ',
#  'coincidence ',
#  'colcannon ',
#  'collaborator ',
#  'collage ',
#  'colleen ',
#  'collusion ',
#  'collywobbles ',
#  'colonel ',
#  'colonial ',
#  'colorimeter ',
#  'comandancia ',
#  'combatant ',
#  'combust ',
#  'comedienne ',
#  'commando ',
#  'commencement ',
#  'commissary ',
#  'commissure ',
#  'commitment ',
#  'committal ',
#  'committeeman ',
#  'commonwealth ',
#  'commutation ',
#  'companion ',
#  'complaint ',
#  'complicity ',
#  'Compositae ',
#  'composite ',
#  'compound ',
#  'compress ',
#  'concatenate ',
#  'concento ',
#  'concerto ',
#  'concession ',
#  'concho ',
#  'concierge ',
#  'conclave ',
#  '',
#  ' \nTheSpellingBeeChamp.wordpress.com ',
#  'PAIDEIA 1998 ',
#  'concomitant ',
#  'concurrent ',
#  'condense ',
#  'condiment ',
#  'condor ',
#  'condottiere ',
#  'confection ',
#  'confinement ',
#  'confrere ',
#  'confrontation ',
#  'Confucian ',
#  'congealed ',
#  'congenital ',
#  'conglomerate ',
#  'congregation ',
#  'conjugate ',
#  'connective ',
#  'connoisseur ',
#  'conquistador ',
#  'consanguinity ',
#  'conscription ',
#  'consecrate ',
#  'consolidationist ',
#  'consort ',
#  'conspiracy ',
#  'constable ',
#  'constabulary ',
#  'constituency ',
#  'constitutional ',
#  'constrict ',
#  'consul ',
#  'contemporaneous ',
#  'conticent ',
#  'contiguous ',
#  'contingent ',
#  'continuity ',
#  'contretemps ',
#  'controversy ',
#  'contumacy ',
#  'convention ',
#  'conversant ',
#  'conversion ',
#  'convoy ',
#  'cooncan ',
#  'coppernose ',
#  'coquetry ',
#  'coquina ',
#  'coral ',
#  'cordillera ',
#  'cordovan ',
#  'cordwinder ',
#  'cornea ',
#  'cornice ',
#  'cornichon ',
#  'cornucopia ',
#  'coronation ',
#  'corposant ',
#  'corpuscle ',
#  'corral ',
#  'correctional ',
#  'corroboration ',
#  'corrode ',
#  'cortex ',
#  'corticoline ',
#  'corundum ',
#  'coruscated ',
#  'corybantic ',
#  'couchant ',
#  'couchette ',
#  'couching ',
#  'coulis ',
#  'coulisse ',
#  'coulometric ',
#  'counterattack ',
#  'counterfeiter ',
#  'counterpane ',
#  'coup ',
#  'courser ',
#  'courtier ',
#  'courtly ',
#  'courtyard ',
#  'covenant ',
#  'coverlet ',
#  'covey ',
#  'cowcatcher ',
#  'cower ',
#  'coyote ',
#  'cranial ',
#  'craquelure ',
#  'crawl ',
#  'craze ',
#  'creatinine ',
#  'creel ',
#  'crest ',
#  'cribbage ',
#  'criminology ',
#  'crinet ',
#  'cringle ',
#  'criollo ',
#  'crochet ',
#  'croquet ',
#  'croquettes ',
#  'crossbow ',
#  'crossover ',
#  'croupier ',
#  'crouton ',
#  'crucible ',
#  'cruiser ',
#  'crumpet ',
#  'crusade ',
#  'cryology ',
#  'cryptanalysis ',
#  'cuckoo ',
#  'Culex ',
#  'culgee ',
#  'culprit ',
#  'culvert ',
#  'cumuli ',
#  'cunctation ',
#  'cupid ',
#  'cupola ',
#  'curbstone ',
#  'curfew ',
#  'curling ',
#  'curriculum ',
#  'curtail ',
#  'cutaneous ',
#  'cyanide ',
#  'cyanosis ',
#  'cybernetics ',
#  'cyclops ',
#  'cyclorama ',
#  'cylindrical ',
#  'cynology ',
#  'cytology ',
#  'cytoplasm ',
#  'dacquoise ',
#  'dactyl ',
#  'dactylion ',
#  'dactyloscopy ',
#  'daedal ',
#  'dandruff ',
#  'dangle ',
#  'dashi ',
#  'dative ',
#  'daven ',
#  'dawdler ',
#  'deadened ',
#  'deadlock ',
#  'debark ',
#  'debilitated ',
#  'debris ',
#  'decalcomania ',
#  'decamerous ',
#  'decathlon ',
#  'decimate ',
#  'decisive ',
#  'declaim ',
#  'decompose ',
#  'decorative ',
#  'decoupage ',
#  'decrepitude ',
#  'decuple ',
#  'defalcation ',
#  'defamation ',
#  'deglaze ',
#  'deltiology ',
#  'demagoguery ',
#  'demarche ',
#  'demesne ',
#  'demigod ',
#  'demijohn ',
#  'demography ',
#  'dendrochronology ',
#  'denouement ',
#  'density ',
#  'deployment ',
#  'deposition ',
#  'depot ',
#  'depredation ',
#  'deprogram ',
#  'derailleur ',
#  'dereliction ',
#  'dermatology ',
#  'deserter ',
#  'designer ',
#  'desman ',
#  'desperado ',
#  'despotic ',
#  'destination ',
#  'destine ',
#  'destitute ',
#  'destrier ',
#  'destroyer ',
#  'detachment ',
#  'detainer ',
#  'detective ',
#  'detent ',
#  'detention ',
#  'deterrence ',
#  'deterrent ',
#  'deuce ',
#  'devotions ',
#  'dewy ',
#  'dexter ',
#  'diabetic ',
#  'diagnosis ',
#  'diamagnetic ',
#  'diastolic ',
#  'diatomic ',
#  'dietetics ',
#  'diffract ',
#  'dignify ',
#  'diktat ',
#  'dilate ',
#  'dilatorily ',
#  'diligent ',
#  'dillydally ',
#  'dimer ',
#  'diplomacy ',
#  'dipolar ',
#  'dipsomania ',
#  'diptych ',
#  'dirigisme ',
#  '',
#  ' \nTheSpellingBeeChamp.wordpress.com ',
#  'PAIDEIA 1998 ',
#  'dirndl ',
#  'disembogue ',
#  'disfranchise ',
#  'disinformation ',
#  'disingenuous ',
#  'dispel ',
#  'disproportionate ',
#  'dissident ',
#  'dissociative ',
#  'distelfink ',
#  'distillation ',
#  'distinct ',
#  'ditokous ',
#  'dittology ',
#  'diva ',
#  'diverge ',
#  'divers ',
#  'diversionary ',
#  'diverticulum ',
#  'Dixiecrat ',
#  'docilely ',
#  'doctrinaire ',
#  'docudrama ',
#  'documentary ',
#  'dogfight ',
#  'dogleg ',
#  'dogma ',
#  'dogwatch ',
#  'doily ',
#  'doldrums ',
#  'doleful ',
#  'domiciliated ',
#  'dominion ',
#  'domino ',
#  'doneness ',
#  'donzella ',
#  'dopester ',
#  'doublet ',
#  'doubloons ',
#  'doughty ',
#  'dovetailed ',
#  'dowlas ',
#  'doxology ',
#  'drab ',
#  'dragnet ',
#  'dramatization ',
#  'dramaturgy ',
#  'drapery ',
#  'dressage ',
#  'dribble ',
#  'drilling ',
#  'drollery ',
#  'drosometer ',
#  'drove ',
#  'druid ',
#  'dryad ',
#  'dual ',
#  'duenna ',
#  'duet ',
#  'dulcet ',
#  'dulcinea ',
#  'dumplings ',
#  'dun ',
#  'duodenum ',
#  'duple ',
#  'duplex ',
#  'duplicate ',
#  ...]

# %%
df = pd.DataFrame(text, columns=['Word'])

# %%
df1 = df.applymap(lambda x: x.replace('\n',''))
df1.dropna(inplace=True)
df1 = df.applymap(lambda x: x.strip())
len(df1
   )
# Out:
# 3337

# %%
df1 = df1[df1['Word']!='']

# %%
df1[df1['Word']=='TheSpellingBeeChamp.wordpress.com ']
# Out:
# Empty DataFrame
# Columns: [Word]
# Index: []

# %%
df1[df1['Word'].str.lower()!='paideia 1998']
# Out:
#              Word
# 0
# 1
# 2
# 3
# 4
# ...           ...
# 3332      zoology
# 3333  Zoroastrian
# 3334     zugzwang
# 3335
# 3336
#
# [3321 rows x 1 columns]

# %%
df1 = df1[(df1['Word'].str.lower()!='paideia 1998')&(df1['Word']!='TheSpellingBeeChamp.wordpress.com')&(df1['Word'].str.lower()!='')]
#(df1['Word']!='
len(df1)
# Out:
# 3268

# %%
df1['Meaning'] = ''
df1
# Out:
# SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy [1306395583.py:1]
#              Word Meaning
# 25        abalone
# 26       abdicate
# 27      abduction
# 28       ablution
# 29       abnormal
# ...           ...     ...
# 3330         ziti
# 3331        zonal
# 3332      zoology
# 3333  Zoroastrian
# 3334     zugzwang
#
# [3268 rows x 2 columns]

# %%
words_without_meaning = df1[df1['Meaning']=='']['Word']
respE = [requests.get(f'https://www.dictionaryapi.com/api/v3/references/collegiate/json/{word}?key={keyid_col}') for word in words_without_meaning]

# %%
respE[0].json()
# Out:
# [{'meta': {'id': 'abalone',
#    'uuid': 'f4ecccf1-31f3-4e24-83a9-6af5ba9d63a5',
#    'sort': '010052000',
#    'src': 'collegiate',
#    'section': 'alpha',
#    'stems': ['abalone', 'abalones'],
#    'offensive': False},
#   'hwi': {'hw': 'ab*a*lo*ne',
#    'prs': [{'mw': 'ˌa-bə-ˈlō-nē',
#      'sound': {'audio': 'abalon02', 'ref': 'c', 'stat': '1'}},
#     {'mw': 'ˈa-bə-ˌlō-nē',
#      'sound': {'audio': 'abalon01', 'ref': 'c', 'stat': '1'}}]},
#   'fl': 'noun',
#   'def': [{'sseq': [[['sense',
#        {'dt': [['text',
#           '{bc}any of a genus ({it}Haliotis{/it}) of edible rock-clinging gastropod mollusks that have a flattened shell slightly spiral in form, lined with mother-of-pearl, and with a row of apertures along its outer edge']]}]]]}],
#   'et': [['text',
#     'American Spanish {it}abulón{/it}, from Rumsen (American Indian language of Monterey Bay, California) {it}aulon{/it}']],
#   'date': '1850',
#   'shortdef': ['any of a genus (Haliotis) of edible rock-clinging gastropod mollusks that have a flattened shell slightly spiral in form, lined with mother-of-pearl, and with a row of apertures along its outer edge']}]

# %%
words = df1

# %%
#def get_word_meaning_mw( words, respE):

all_rows = []
missing_words = []
words_without_meaning = words[words['Meaning']=='']['Word']
# respE = [requests.get(f'https://www.dictionaryapi.com/api/v3/references/collegiate/json/{word}?key={keyid_col}') for word in words_without_meaning]

all_rows = []
meta_dict = {}
meta_cnt = 0
set_miss_word_dict = {}
#filename = 'L1A'
#filepath = file #'/Users/hema/Downloads'
print(all_rows)
aud_cnt = 1
for idx, res in enumerate(respE):   
    ids = ''
    stems = ''
    fls = ''
    hwis = ''
    shdef = ''
    ets = ''
    prss = ''
    audios = ''
    audio = []
    audio_filename = ''
    data = (res.json())
    #print(data)
    print('=============================================')
    if "'meta'" not in str(data):
          missing_words.append(words.iloc[idx,:].values[0])
    else :
        for meta in data:
                aud_cnt += 1
                for key, item in meta.items():
                    meta_dict[key] = item 
                    for key, item in meta_dict.items():
                        if key=='meta':
                            for k,i in item.items():
                                if k=='id':
                                    ids= i
                                if k=='stems':
                                    stems = i

                        if key=='fl':
                            fls = item

                        if key=='hwi':

                            for k,i in item.items():
                                if k=='prs':                            
                                    prs_keys = (i[0].items())
                                    for key,pro in prs_keys:
                                        if key=='mw':
                                            prss=pro
                                        if key=='sound':
                                            audios=pro['audio']
                                            aud = pro['audio']
                                            if re.match('^gg*', aud):
                                                fol = 'gg'
                                            elif re.match('^[a-zA-Z]', aud):
                                                fol = aud[0]
                                            else:
                                                fol = 'number'




                        if key=='shortdef':
                            if len(item) != 0:
                                shdef = item[0]


                        if key=='et':
                            if len(item) != 0:
                                ets = item[0][1]

#                 row = (ids, stems, fls, prss, audio_link, shdef, ets, audio_filepath)
                #row = (ids, prss, ets, shdef)
                row = (ids, shdef)
                print(row)
                all_rows.append(row)
        #print(all_rows)

df_all = pd.DataFrame(all_rows, columns=['Word', 'Short Definition']) 

#add the meaning to the word df
for w in words_without_meaning:
    #print(df_all.loc[df_all['Word']==w,'Short Definition'].values[0])
    words.loc[words['Word']==w,'Meaning'] = df_all.loc[df_all['Word']==w,'Short Definition'].values
#return words, df_all

#write the meaning to the source excel/csv file
# Out:
# []
# =============================================
# ('abalone', 'any of a genus (Haliotis) of edible rock-clinging gastropod mollusks that have a flattened shell slightly spiral in form, lined with mother-of-pearl, and with a row of apertures along its outer edge')
# =============================================
# ('abdicate', 'to renounce a throne, high office, dignity, or function')
# =============================================
# ('abduction', 'the action of abducting : the condition of being abducted')
# =============================================
# ('ablution', "the washing of one's body or part of it (as in a religious rite) —usually plural")
# =============================================
# ('abnormal:1', 'deviating from the normal or average; often : unusual in an unwelcome or problematic way')
# ('abnormal:2', 'an abnormal person')
# ('abnormal psychology', 'a branch of psychology concerned with mental and emotional disorders (such as anxiety disorders, phobias, depression, and developmental disorders) and with certain incompletely understood normal phenomena (such as dreams and hypnosis)')
# =============================================
# =============================================
# ('aboriginal:1', 'being the first or earliest known of its kind present in a region')
# =============================================
# ('absolution', 'the act of forgiving someone for having done something wrong or sinful : the act of absolving someone or the state of being absolved; specifically : a remission of sins pronounced by a priest (as in the sacrament of reconciliation)')
# =============================================
# ('abstention', 'the act or practice of abstaining: such as')
# =============================================
# ('academe', 'a place of instruction')
# ('groves of academe', 'the academic world')
# =============================================
# ('academia', 'the life, community, or world of teachers, schools, and education : academe')
# =============================================
# ('academician', 'a member of an academy for promoting science, art, or literature')
# =============================================
# ('acanthus', 'any of a genus (Acanthus of the family Acanthaceae, the acanthus family) of prickly perennial herbs chiefly of the Mediterranean region')
# =============================================
# ('accipiter', 'any of a genus (Accipiter) of medium-sized forest-inhabiting hawks that have short broad wings and a long tail and a characteristic flight pattern of several quick flaps and a glide')
# =============================================
# ('acclamation', 'a loud eager expression of approval, praise, or assent')
# =============================================
# ('accommodation', 'something supplied for convenience or to satisfy a need: such as')
# ('accommodation ladder', 'a light ladder or stairway hung over the side of a ship for ascending from or descending to small boats')
# =============================================
# ('accomplice', 'one associated with another especially in wrongdoing')
# =============================================
# ('accretion', 'the process of growth or enlargement by a gradual buildup: such as')
# =============================================
# ('accumulate', 'to gather or pile up especially little by little : amass')
# =============================================
# ('acedia', 'apathy, boredom')
# =============================================
# ('acetabulum', 'a ventral sucker of a trematode')
# =============================================
# ('acetic acid', 'a colorless pungent liquid acid C2H4O2 that is the chief acid of vinegar and that is used especially in synthesis (as of plastics)')
# ('acetic anhydride', 'a colorless liquid C4H6O3 with a pungent odor used in organic synthesis (as of cellulose acetate and aspirin)')
# =============================================
# ('acetone', 'a volatile fragrant flammable liquid ketone C3H6O used chiefly as a solvent and in organic synthesis and found in abnormal quantities in diabetic urine')
# =============================================
# ('acetylcholine', 'a neurotransmitter [C7H16NO2]+ released at autonomic synapses and neuromuscular junctions and formed enzymatically in the tissues from choline')
# =============================================
# =============================================
# =============================================
# ('achondroplasia', 'a genetic disorder that is marked by abnormally slow conversion of cartilage to bone during development resulting in a form of dwarfism characterized by a usually normal torso and shortened limbs and that is usually inherited as an autosomal dominant trait')
# =============================================
# =============================================
# ('acolyte', 'one who assists a member of the clergy in a liturgical service by performing minor duties')
# =============================================
# ('acoustics', 'a science that deals with the production, control, transmission, reception, and effects of sound')
# =============================================
# =============================================
# ('acrolect', 'the language variety of a speech community closest to the standard or prestige form of a language')
# =============================================
# ('actinide', 'any of the series of elements with increasing atomic numbers that begins with actinium or thorium and ends with lawrencium')
# =============================================
# ('adder:1', 'the common venomous viper (Vipera berus) of Europe; broadly : any of various snakes of the viper family')
# ('adder:2', 'one that adds; especially : a device (as in a computer) that performs addition')
# ("adder's-tongue", "any of a genus (Ophioglossum, family Ophioglossaceae) of small ferns having a spore-bearing stalk resembling a serpent's tongue")
# ('puff adder', 'a large thick-bodied extremely venomous African viper (Bitis arietans)')
# ('hognose snake', 'any of a genus (Heterodon) of rather small harmless stout-bodied North American colubrid snakes with keeled scales and an upturned snout that seldom bite but hiss wildly and often play dead when disturbed —called also hog-nosed snake, puff adder')
# =============================================
# =============================================
# ('adios', '—used to express farewell')
# =============================================
# ('adjournment', 'the act of adjourning')
# =============================================
# =============================================
# ('admonish', 'to indicate duties or obligations to')
# =============================================
# ('adobe', 'a brick or building material of sun-dried earth and straw')
# =============================================
# ('adobo', 'a Philippine dish of fish or meat usually marinated in a sauce containing vinegar and garlic, browned in fat, and simmered in the marinade')
# =============================================
# ('adolescence', 'the period of life when a child develops into an adult : the period from puberty to maturity terminating legally at the age of majority')
# =============================================
# ('Adonis', 'a youth loved by Aphrodite who is killed at hunting by a wild boar and restored to Aphrodite from Hades for a part of each year')
# =============================================
# =============================================
# =============================================
# ('adversary:1', 'one that contends with, opposes, or resists : an enemy or opponent')
# ('adversary:2', 'of, relating to, or involving an enemy or adversary')
# =============================================
# =============================================
# =============================================
# ('aerodynamics', 'a branch of dynamics that deals with the motion of air and other gaseous fluids and with the forces acting on bodies in motion relative to such fluids')
# =============================================
# =============================================
# ('aeronautics', 'a science dealing with the operation of aircraft')
# =============================================
# ('aerosol', 'a suspension of fine solid or liquid particles in gas; also, aerosols plural : the fine particles of an aerosol')
# =============================================
# ('Aesculapian', 'of or relating to Aesculapius or the healing art')
# =============================================
# ('Aesir', 'the principal race of Norse gods')
# =============================================
# ('Aesopian', 'of, relating to, or characteristic of Aesop or his fables')
# =============================================
# ('affidavit', 'a sworn statement in writing made especially under oath or on affirmation before an authorized magistrate or officer')
# =============================================
# ('affinity:1', 'relationship by marriage')
# ('affinity:2', 'of, relating to, involving, or used in affinity chromatography')
# ('affinity card', 'a credit card which is issued in affiliation with a participating organization (such as a charity or an airline) and the use of which earns a benefit for the organization or the cardholder')
# ('affinity chromatography', 'chromatography in which a macromolecule (such as a protein) is isolated and purified by passing it in solution through a column treated with a substance having a ligand for which the macromolecule has an affinity that causes it to be retained on the column')
# ('affinity group', 'a group of people having a common interest or goal or acting together for a specific purpose (as for a chartered tour)')
# =============================================
# ('afflatus', 'a divine imparting of knowledge or power : inspiration')
# =============================================
# =============================================
# ('agape:1', 'wide open : gaping')
# ('agape:2', 'love feast')
# =============================================
# ('agate', 'a fine-grained variegated chalcedony having its colors arranged in stripes, blended in clouds, or showing mosslike forms')
# ('agate line', 'a space one column wide and 1/14 inch deep used as a unit of measurement in classified advertising')
# ('Agate Fossil Beds National Monument:g', 'reservation along the Niobrara River in western Nebraska')
# ('moss agate', 'an agate mineral containing brown, black, or green mosslike or dendritic markings')
# ('agateware', 'an enameled iron or steel ware for household utensils')
# =============================================
# ('aggie:1', 'an agricultural school or college; also : a student at such an institution')
# ('aggie:2', 'a playing marble; specifically : agate')
# =============================================
# ('agglutinate:1', 'to cause to adhere : fasten')
# ('agglutinate:2', 'a clump of agglutinated material (such as blood cells or mineral particles in soil)')
# =============================================
# ('aggregate:1', 'formed by the collection of units or particles into a body, mass, or amount : collective: such as')
# ('aggregate:2', 'to collect or gather into a mass or whole')
# ('aggregate:3', 'a mass or body of units or parts somewhat loosely associated with one another')
# ('monetary aggregate', 'one of the formal categories of money (such as cash and demand deposits or bank credits) in a national economy that is used as a measure in predictions of economic growth')
# ('on aggregate', 'with the scores of a series of matches added together')
# =============================================
# ('agnostic:1', 'a person who holds the view that any ultimate reality (such as God) is unknown and probably unknowable; broadly : one who is not committed to believing in either the existence or the nonexistence of God or a god')
# ('agnostic:2', 'of, relating to, or being an agnostic : involving or characterized by agnosticism')
# =============================================
# ('agonal', 'marked by or characteristic of agony')
# =============================================
# ('agrarianism', 'a social or political movement designed to bring about land reforms or to improve the economic status of the farmer')
# =============================================
# ('agronomy', 'a branch of agriculture dealing with field-crop production and soil management')
# =============================================
# ('ahimsa', 'the Hindu and Buddhist doctrine of refraining from harming any living being')
# =============================================
# ('a horse of a different color', 'a very different thing or issue')
# ('beat a dead horse', 'to keep talking about a subject that has already been discussed or decided')
# ('eat a horse', '—used to illustrate that someone is very hungry')
# ('flog a dead horse', 'to keep talking about a subject that has already been discussed or decided')
# ('look a gift horse in the mouth', 'to look in a critical way at something that has been given to one')
# =============================================
# ('aiguillette', 'aglet; specifically : a shoulder cord worn by designated military aides')
# =============================================
# ('aileron', 'a movable airfoil at the trailing edge of an airplane wing that is used for imparting a rolling motion especially in banking for turns')
# ('Frise aileron', 'an aileron having a nose portion projecting ahead of the hinge axis and a lower surface in line with the lower surface of the wing')
# =============================================
# =============================================
# ('aioli', 'a mayonnaise flavored with garlic and sometimes other ingredients (such as red pepper)')
# =============================================
# =============================================
# ('alabaster', 'a compact fine-textured usually white and translucent gypsum often carved into vases and ornaments')
# ('Alabaster:g', 'city in central Alabama south of Birmingham population 30,352')
# =============================================
# ('alchemy', 'a medieval chemical science and speculative philosophy aiming to achieve the transmutation of the base metals into gold, the discovery of a universal cure for disease, and the discovery of a means of indefinitely prolonging life')
# =============================================
# ('alcove', 'a small recessed section of a room : nook')
# =============================================
# ('aldehyde', 'acetaldehyde; broadly : any of a class of highly reactive organic compounds that are analogous to acetaldehyde and characterized by a carbonyl group attached to a hydrogen atom')
# =============================================
# ('alderman', 'a person governing a kingdom, district, or shire as viceroy for an Anglo-Saxon king')
# =============================================
# ('aldosterone', 'a steroid hormone C21H28O5 of the adrenal cortex that functions in the regulation of the salt and water balance of the body')
# =============================================
# ('alembic', 'an apparatus used in distillation')
# =============================================
# ('alfalfa', 'a deep-rooted leguminous perennial plant (Medicago sativa) of southwestern Asia that is widely grown for hay and forage')
# ('alfalfa weevil', 'a small dark brown European weevil (Hypera postica) that is now a widespread pest of alfalfa in North America')
# ('Egyptian alfalfa weevil', 'an Old World weevil (Hypera brunneipennis) that is now a pest of alfalfa in western North America')
# ('spotted alfalfa aphid', 'a highly destructive Old World aphid (Therioaphis maculata) that is established in the U.S. in warmer areas and causes yellowing and stunting of affected plants')
# =============================================
# ('algid', 'cold')
# =============================================
# ('alias:1', 'otherwise called : otherwise known as —used to indicate an additional name that a person (such as a criminal) sometimes uses')
# ('alias:2', 'an assumed or additional name that a person (such as a criminal) sometimes uses')
# ('under an alias', 'using an assumed name')
# =============================================
# ('alibi:1', 'the plea of having been at the time of the commission of an act elsewhere than at the place of commission; also : the fact or state of having been elsewhere at the time')
# ('alibi:2', 'to exonerate (someone) by an alibi : to furnish an excuse for')
# ('alibi witness', 'a witness upon whom a criminal defendant relies in establishing or providing an alibi')
# =============================================
# =============================================
# ('alkaline', 'of, relating to, containing, or having the properties of an alkali or alkali metal : basic; especially, of a solution : having a pH of more than 7')
# ('alkaline battery', 'a long-lived dry cell with an alkaline electrolyte that decreases corrosion of the cell —called also alkaline cell')
# ('alkaline earth metal', 'any of the divalent strongly basic metals of group II of the periodic table comprising beryllium, magnesium, calcium, strontium, barium, and radium —called also alkaline earth')
# ('alkaline hydrolysis', 'the chemical process of rapidly decomposing a dead body to mostly tiny bits of bone resembling ash by immersing the body in a pressurized chamber containing a heated alkaline solution (as of potassium hydroxide) followed by drainage of all liquid and pulverization of remaining bone; broadly : any hydrolysis process performed in an alkaline environment')
# ('alkaline phosphatase', 'any of the phosphatases that are optimally active in alkaline medium and occur in especially high concentrations in bone, the liver, the kidneys, and the placenta')
# =============================================
# ('alkane', 'any of numerous saturated hydrocarbons; specifically : any of a series of open-chain hydrocarbons CnH2n+2 (such as methane and butane) —called also paraffin')
# =============================================
# ('allotropy', 'the existence of a substance and especially an element in two or more different forms (as of crystals) usually in the same phase')
# =============================================
# ('allure:1', 'to entice by charm or attraction')
# ('allure:2', 'power of attraction or fascination : charm')
# =============================================
# ('alpaca', 'a domesticated mammal (Vicugna pacos synonym Lama pacos) especially of Peru that is probably descended from the vicuña')
# =============================================
# ('alpenglow', 'a reddish glow seen near sunset or sunrise on the summits of mountains')
# =============================================
# ('alstroemeria', 'any of a genus (Alstroemeria) of tropical South American herbs of the lily family that are often cultivated for their clusters of showy variegated flowers')
# =============================================
# ('altarpiece', 'a work of art that decorates the space above and behind an altar')
# =============================================
# ('altiplano', 'a high plateau or plain : tableland')
# =============================================
# ('alveolar', 'of, relating to, resembling, or having alveoli; especially : of, relating to, or constituting the part of the jaws where the teeth arise, the air-containing compartments of the lungs, or glands with secretory cells about a central space')
# ('alveolar process', 'the bony ridge or raised thickened border of the upper or lower jaw that contains the sockets of the teeth : alveolar ridge')
# ('alveolar ridge', 'the bony ridge or raised thickened border of the upper or lower jaw that contains the sockets of the teeth : alveolar process')
# =============================================
# ('alyssum', 'any of a genus (Alyssum) of Eurasian herbs of the mustard family with small usually yellow racemose flowers —called also madwort')
# ('sweet alyssum', 'a widely cultivated European herb (Lobularia maritima) of the mustard family having narrow leaves and clusters of small fragrant usually white or pink flowers')
# =============================================
# ('amalgam', 'a mixture of different elements')
# =============================================
# ('amandine', 'prepared or served with almonds')
# =============================================
# ('amass', 'to collect for oneself : accumulate')
# =============================================
# ('amaurosis', 'partial or complete loss of sight occurring especially without an externally perceptible change in the eye')
# =============================================
# ('ambrosia', 'the food of the Greek and Roman gods')
# ('ambrosia beetle', 'any of various small wood-boring beetles (family Scolytidae) that cultivate a fungus on which they feed and raise their larvae')
# =============================================
# ('ambush:1', 'to attack by surprise from a hidden place : waylay')
# ('ambush:2', 'a trap in which one or more concealed attackers lie in wait to attack by surprise')
# =============================================
# ('amerce', 'to punish by a fine whose amount is fixed by the court; broadly : punish')
# =============================================
# ('amigo', 'friend')
# =============================================
# ('amine', 'any of a class of basic organic compounds derived from ammonia by replacement of hydrogen with one or more monovalent hydrocarbon radicals')
# ('heterocyclic amine', 'an amine containing one or more closed rings of carbon and nitrogen; especially : any of various carcinogenic amines formed when creatine or creatinine reacts with free amino acids and sugar in meat cooked at high temperatures')
# =============================================
# ('ammoniac', 'the aromatic gum resin of a southwest Asian herb (Dorema ammoniacum) of the carrot family used as an expectorant and stimulant and in plasters')
# ('ammoniacal', 'of, relating to, containing, or resembling ammonia')
# ('sal ammoniac', 'ammonium chloride')
# ('ammonium chloride', 'a white crystalline volatile salt NH4Cl that is used in dry cells and as an expectorant —called also sal ammoniac')
# =============================================
# ('ammunition', 'the projectiles with their fuses, propelling charges, or primers fired from guns')
# =============================================
# ('amnesty:1', 'the act of an authority (such as a government) by which pardon is granted to a large group of individuals')
# ('amnesty:2', 'to grant amnesty to : to pardon (someone) officially often before a trial or conviction')
# =============================================
# =============================================
# ('amorphous', 'having no definite form : shapeless')
# =============================================
# ('amphibious', 'combining two characteristics')
# =============================================
# ('amphoteric', 'partly one and partly the other; specifically : capable of reacting chemically either as an acid or as a base')
# =============================================
# =============================================
# ('anabasis', 'a going or marching up : advance; especially : a military advance')
# =============================================
# ('anachronism', 'an error in chronology; especially : a chronological misplacing of persons, events, objects, or customs in regard to each other')
# =============================================
# ('anaglyph', 'a sculptured, chased, or embossed ornament worked in low relief')
# =============================================
# ('anamnesis', 'a recalling to mind : reminiscence')
# =============================================
# ('anarchy', 'absence of government')
# =============================================
# ('anastomosis', 'the union of parts or branches (as of streams, blood vessels, or leaf veins) so as to intercommunicate or interconnect')
# =============================================
# ('anathema', 'someone or something intensely disliked or loathed —usually used as a predicate nominative')
# =============================================
# ('ancestor', 'one from whom a person is descended and who is usually more remote in the line of descent than a grandparent')
# ('ancestor worship', 'the custom of venerating deceased ancestors who are considered still a part of the family and whose spirits are believed to have the power to intervene in the affairs of the living')
# =============================================
# ('anchovy', 'any of a family (Engraulidae) of small fishes resembling herrings that includes several (such as Engraulis encrasicholus) that are important food fishes used especially in appetizers, as a garnish, and for making sauces and relishes')
# =============================================
# ('ancient:1', 'having had an existence of many years')
# ('ancient:2', 'a person who lived in ancient times:')
# ('ancient:3', 'ensign, standard, flag')
# ('ancient history', 'the history of ancient times')
# =============================================
# ('ancilla', 'an aid to achieving or mastering something difficult')
# =============================================
# ('andante:1', 'moderately slow —usually used as a direction in music')
# ('andante:2', 'a musical composition or movement in andante tempo')
# =============================================
# =============================================
# =============================================
# =============================================
# ('creme anglaise', 'a vanilla-flavored custard sauce usually served with desserts')
# =============================================
# ('angst:1', 'a feeling of anxiety, apprehension, or insecurity')
# ('angst:2', 'to feel or express anxiety, apprehension, or insecurity : to experience or express angst — often used with over or about')
# =============================================
# ('anhydrous', 'free from water and especially water of crystallization')
# =============================================
# ('animadversion', 'a critical and usually censorious remark —often used with on')
# =============================================
# ('animism', 'a doctrine that the vital principle of organic development is immaterial spirit')
# =============================================
# ('anionic', 'of or relating to anions')
# =============================================
# ('anneal', 'to heat and then cool (a material, such as steel or glass) usually for softening and making less brittle; also : to cool slowly usually in a furnace')
# =============================================
# ('annexation', 'the act of annexing something or the state of being annexed : the addition of an area or region to a country, state, etc.')
# =============================================
# ('anniversary', 'the annual recurrence of a date marking a notable event; broadly : a date that follows such an event by a specified period of time measured in units other than years')
# =============================================
# ('annulet', 'a little ring')
# =============================================
# ('anon:1', 'soon, presently')
# ('anon:2', 'anonymous; anonymously')
# ('angle:1', 'a corner whether constituting a projecting part or a partially enclosed space')
# ('ever', 'always')
# ('keep:1', "to retain in one's possession or power")
# ('non-A, non-B hepatitis', 'hepatitis clinically similar to hepatitis A and hepatitis B but caused by a different virus; especially : hepatitis c')
# ("an attempt on someone's life", 'an act of trying to kill someone : a usually unsuccessful effort to kill someone')
# ('have/keep half an eye on', 'to be only partly paying attention to : to look at occasionally')
# ('keep an eagle eye on', 'to watch (someone or something) very closely')
# ("make an attempt on someone's life", 'to try to kill someone')
# =============================================
# ('Anschluss:f', 'union —used especially in reference to the forcible uniting of Germany and Austria in 1938')
# =============================================
# ('Antaean', 'mammoth')
# =============================================
# ('antagonist', 'one that contends with or opposes another : adversary, opponent')
# =============================================
# ('ante:1', 'a poker stake usually put up before the deal to build the pot')
# ('ante:2', 'to put up (an ante); also : pay, produce —usually used with up')
# ('ante-', 'prior : earlier')
# ('ante meridiem', 'being before noon —abbreviation AM, a.m., or (British) am')
# ('ante-post', 'relating to or being wagers on a horse race made especially before the day of the race')
# ('penny-ante', 'small-time, two-bit')
# ('penny ante', 'poker played for very low stakes')
# ('status quo ante', 'the state of affairs that existed previously')
# ('pereant qui ante nos nostra dixerunt:f', 'may they perish who have uttered ours (our ideas) before us')
# ('status quo ante bellum:f', 'the state existing before the war')
# =============================================
# ('antebellum', 'existing before a war; especially : existing before the American Civil War')
# ('status quo ante bellum:f', 'the state existing before the war')
# =============================================
# ('antecessor', 'one that goes before : predecessor')
# =============================================
# ('antediluvian', 'of or relating to the period before the flood described in the Bible')
# =============================================
# =============================================
# ('anticlimax', 'the usually sudden transition in discourse from a significant idea to a trivial or ludicrous idea; also : an instance of this transition')
# =============================================
# ('antiquarian:1', 'one who collects or studies antiquities')
# ('antiquarian:2', 'of or relating to antiquarians or antiquities')
# =============================================
# ('antiquity', 'ancient times; especially : those before the Middle Ages')
# =============================================
# ('aorist', 'an inflectional form of a verb typically denoting simple occurrence of an action without reference to its completeness, duration, or repetition')
# =============================================
# ('aorta', 'the great arterial trunk that carries blood from the heart to be distributed by branch arteries through the body')
# ('arch of the aorta', 'the curved part of the aorta that connects the ascending aorta with the descending aorta and from which the brachiocephalic artery, left carotid artery, and left subclavian artery arise —called also aortic arch')
# =============================================
# ('aparejo', 'a packsaddle of stuffed leather or canvas')
# =============================================
# ('aphasia', 'loss or impairment of the power to use or comprehend words usually resulting from brain damage (as from a stroke, head injury, or infection)')
# =============================================
# ('apodictic', 'expressing or of the nature of necessary truth or absolute certainty')
# =============================================
# ('Apollonian:1', 'of, relating to, or resembling the god Apollo')
# ('Apollonian:2', 'of, relating to, or characteristic of the Greek poet Apollonius or his writings')
# ('Apollonius:b', 'of Rhodes 3rd century b.c. Greek poet')
# =============================================
# ('apostate', 'one who commits apostasy')
# =============================================
# ('apostle', 'one sent on a mission: such as')
# ('Apostle Islands:g', 'group of islands in southwestern Lake Superior off the northwestern coast of Wisconsin preserved as part of Apostle Islands National Lakeshore')
# =============================================
# ('apotheosis', 'the perfect form or example of something : quintessence')
# =============================================
# ('apparatchik', 'a member of a Communist apparat')
# =============================================
# =============================================
# ('appeasement', 'the act or action of appeasing someone or something; especially : a policy of appeasing an enemy or potential aggressor by making concessions')
# =============================================
# ('appellate', 'of, relating to, or recognizing appeals; specifically : having the power to review the judgment of another tribunal')
# =============================================
# =============================================
# =============================================
# ('apprehend', 'arrest, seize')
# =============================================
# ('aqua', 'water; especially : water')
# ('aqua fortis', 'nitric acid')
# ('Aqua-Lung', '—used for an underwater breathing apparatus')
# ('aqua regia', 'a mixture of nitric and hydrochloric acids that dissolves gold or platinum')
# ('aqua vitae', 'a strong alcoholic liquor (such as brandy)')
# ('aqua et igni interdictus:f', 'forbidden (to be furnished) with water and fire : banished')
# ('sub-aqua', 'relating to activities done under water : underwater')
# =============================================
# ('aqueous', 'of, relating to, or resembling water')
# ('aqueous humor', 'a transparent fluid occupying the space between the crystalline lens and the cornea of the eye')
# =============================================
# ('aquiline', "curving like an eagle's beak")
# =============================================
# ('arabesque:1', 'an ornament or style that employs flower, foliage, or fruit and sometimes animal and figural outlines to produce an intricate pattern of interlaced lines')
# ('arabesque:2', 'of, relating to, or being in the style of arabesque or an arabesque')
# =============================================
# ('arachnoid:1', 'of or relating to a thin membrane of the brain and spinal cord that lies between the dura mater and the pia mater')
# ('arachnoid:2', 'an arachnoid membrane')
# ('arachnoid:3', 'resembling or related to the arachnids')
# =============================================
# =============================================
# ('arboriculture', 'the cultivation of trees and shrubs especially for ornamental purposes')
# =============================================
# ('arbutus', 'any of a genus (Arbutus) of shrubs and trees of the heath family with white or pink flowers and red or orange berries')
# ('trailing arbutus', 'arbutus')
# =============================================
# ('arcaded', 'having, formed in, or decorated with arches or arcades')
# =============================================
# ('arcane', 'known or knowable only to a few people : secret; broadly : mysterious, obscure')
# =============================================
# ('archaic', 'having the characteristics of the language of the past and surviving chiefly in specialized uses')
# ('archaic smile', 'an expression that resembles a smile and is characteristic of early Greek sculpture')
# =============================================
# ('archangel', 'a chief angel')
# ("Arkhangel'sk:g", 'city and port on the Northern Dvina River near its mouth in the European part of Russia population 414,000')
# ('Dvina Bay:g', 'arm of the White Sea in northern Russia in Europe')
# =============================================
# ('archery', 'the art, practice, or skill of shooting with bow and arrow')
# =============================================
# ('architecture', 'the art or science of building; specifically : the art or practice of designing and building structures and especially habitable ones')
# ('Norman architecture', 'a Romanesque style first appearing in and near Normandy about a.d. 950; also : architecture resembling or imitating this style')
# ('landscape architect', 'a person who develops land for human use and enjoyment through effective placement of structures, vehicular and pedestrian ways, and plantings')
# ('marine architect', 'naval architect')
# =============================================
# ('architrave', 'the lowest division of an entablature resting in classical architecture immediately on the capital of the column')
# =============================================
# =============================================
# ('argent', 'the metal silver; also : whiteness')
# =============================================
# ('argonaut', 'any of a band of heroes sailing with Jason in quest of the Golden Fleece')
# =============================================
# ('arietta', 'a short aria')
# =============================================
# ('armada', 'a fleet of warships')
# =============================================
# ('armadillo', 'any of a family (Dasypodidae) of burrowing edentate mammals found from the southern U.S. to Argentina and having the body and head encased in an armor of small bony plates')
# =============================================
# ('armament', 'a military or naval force')
# =============================================
# ('armature', 'an organ or structure (such as teeth or thorns) for offense or defense')
# =============================================
# ('armiger', 'squire')
# =============================================
# ('armistice', 'temporary stopping of open acts of warfare by agreement between the opponents : truce')
# ('Armistice Day', 'veterans day —used before the official adoption of Veterans Day in 1954')
# =============================================
# ('arrear', 'the state of being behind in the discharge of obligations —usually used in plural')
# ('in arrears with', 'behind in (making payments that have come due)')
# =============================================
# ('arrestee', 'a person who is under arrest')
# =============================================
# ('arrondissement', 'an administrative district of some large French cities')
# =============================================
# ('arsenic:1', 'a solid chemical element that is used especially in wood preservatives, alloys, and semiconductors and is extremely toxic in both pure and combined forms')
# ('arsenic:2', 'of, relating to, or containing arsenic especially with a valence of five')
# =============================================
# ('arson', 'the willful or malicious burning of property (such as a building) especially with criminal or fraudulent intent')
# =============================================
# ('artery', 'any of the tubular branching muscular- and elastic-walled vessels that carry blood from the heart through the body')
# ('brachiocephalic artery', 'a short artery that arises from the arch of the aorta and divides into the carotid and subclavian arteries of the right side —called also innominate artery')
# ('carotid artery', 'either of the two main arteries that supply blood to the head of which the left in humans arises from the arch of the aorta and the right by bifurcation of the brachiocephalic artery with each passing up the side of the neck and dividing opposite the upper border of the thyroid cartilage into an external branch supplying the face, tongue, and external parts of the head and an internal branch supplying the brain, eye, and other internal parts of the head')
# ('cerebral artery', 'any of the arteries supplying the cerebral cortex')
# ('coronary artery', 'either of two arteries that arise one from the left and one from the right side of the aorta immediately above the semilunar valves and supply the tissues of the heart itself')
# ('coronary artery bypass', 'a surgical procedure performed to shunt blood around a narrowing or blockage in the coronary artery of the heart that usually involves grafting one end of a segment of blood vessel (such as a vein of the leg) removed from another part of the body into the aorta and the other end of the segment into the coronary artery beyond the obstructed area to allow for increased blood flow —often followed by the word surgery or operation —abbreviation CABG')
# ('femoral artery', 'the chief artery of the thigh lying in its anterior inner part')
# ('innominate artery', 'brachiocephalic artery')
# ('pulmonary artery', 'an artery that conveys venous blood from the heart to the lungs')
# ('subclavian artery', 'the proximal part of the main artery of the arm or forelimb')
# =============================================
# ('Arthurian', 'of or relating to King Arthur and his court')
# =============================================
# ('articulate:1', 'expressing oneself readily, clearly, and effectively; also : expressed in such a manner')
# ('articulate:2', 'to give clear and effective utterance to : to put into words')
# =============================================
# ('artillery', 'weapons (such as bows, slings, and catapults) for discharging missiles')
# ('artillery pieces', 'large guns that shoot over long distances')
# ('field artillery', 'artillery other than antiaircraft artillery used with armies in the field')
# ('heavy artillery', 'a more powerful version of something')
# =============================================
# =============================================
# ('aryl', 'having or being a monovalent organic radical (such as phenyl) derived from an aromatic hydrocarbon by the removal of one hydrogen atom —often used in combination')
# =============================================
# ('ascension', 'the act or process of ascending')
# ('Ascension:g', 'isolated island in the South Atlantic belonging to the British colony of Saint Helena area 34 square miles (88 square kilometers), population 1400')
# ('Ascension Day', "the Thursday 40 days after Easter observed in commemoration of Christ's ascension into Heaven")
# ('right ascension', 'the arc of the celestial equator between the vernal equinox and the point where the hour circle through a given body intersects the equator reckoned eastward commonly in terms of the corresponding interval of sidereal time in hours, minutes, and seconds')
# ('the Ascension', "the Christian holiday that celebrates Jesus Christ's journey to heaven after his death")
# =============================================
# ('asphodel', 'any of various Old World herbs (especially genera Asphodelus and Asphodeline) of the lily family with flowers in usually long erect racemes')
# ('bog asphodel', 'either of two bog herbs (Narthecium ossifragum of Europe and N. americanum of the U.S.) of the lily family')
# =============================================
# ('aspic:1', 'asp')
# ('aspic:2', 'a clear savory jelly (as of fish or meat stock) used as a garnish or to make a meat, fish, or vegetable mold')
# =============================================
# ('assassination', 'murder by sudden or secret attack often for political reasons : the act or an instance of assassinating someone (such as a prominent political leader)')
# ('character assassination', 'the slandering of a person usually with the intention of destroying public confidence in that person')
# =============================================
# ('assault:1', 'a violent physical or verbal attack')
# ('assault:2', 'to make an assault on : to attack violently')
# ('assault boat', 'a small portable boat used in an amphibious military attack or in land warfare for crossing rivers or lakes')
# ('assault rifle', 'any of various intermediate-range, magazine-fed military rifles (such as the AK-47) that can be set for automatic or semiautomatic fire; also : a rifle that resembles a military assault rifle but is designed to allow only semiautomatic fire')
# ('assault weapon', 'any of various automatic or semiautomatic firearms; especially : assault rifle')
# ('assault and battery', 'the crime of threatening and physically hitting or attacking someone')
# ('assault course', 'a training area for soldiers that is filled with objects (such as hurdles, ditches, walls, etc.) that the soldiers have to jump or climb over, go around, go under, etc. : obstacle course')
# ('aggravated assault', 'an assault that is more serious than a common assault: such as')
# ('indecent assault', 'an offensive sexual act or series of acts exclusive of rape committed against another person without consent')
# ('sexual assault', 'illegal sexual contact that usually involves force upon a person without consent or is inflicted upon a person who is incapable of giving consent (as because of age or physical or mental incapacity) or who places the assailant (such as a doctor) in a position of trust or authority')
# =============================================
# ('assemble', 'to bring together (as in a particular place or for a particular purpose)')
# ('self-assembly', 'the process by which a complex macromolecule (such as collagen) or a supramolecular system (such as a virus) spontaneously assembles itself from its components')
# =============================================
# ('assignment', 'the act of assigning something')
# ('self-assignment', 'the act of assigning something (such as a task) to oneself; also : the task or work that is assigned')
# =============================================
# ('Assisi:g', 'commune in central Italy east-southeast of Perugia population 25,637')
# ('Clare of Assisi:b', 'Saint 1194—1253 Italian religious')
# ('Francis of Assisi:b', 'Saint 1181(or 1182)—1226 Francesco di Pietro di Bernardone Italian friar; founder of Franciscan order')
# =============================================
# ('asterisk:1', 'the character used in printing or writing as a reference mark, as an indication of the omission of letters or words, to denote a hypothetical or unattested linguistic form, or for various arbitrary meanings')
# ('asterisk:2', 'to mark with an asterisk : star')
# =============================================
# ('astrologer', 'a person who practices astrology')
# =============================================
# ('asynchrony', 'the quality or state of being asynchronous : absence or lack of concurrence in time')
# =============================================
# ('atlas', "a Titan who for his part in the Titans' revolt against the gods is forced by Zeus to support the heavens on his shoulders")
# ('Atlas Mountains:g', 'mountains of northwestern Africa extending from southwestern Morocco to northeastern Tunisia; the highest peaks are in the Grand Atlas (also known as the High Atlas) in southwest central Morocco')
# ('dialect atlas', 'linguistic atlas')
# ('linguistic atlas', 'a publication containing a set of maps on which speech variations are recorded —called also dialect atlas')
# =============================================
# =============================================
# ('atmospheric', 'of, relating to, or occurring in the atmosphere')
# =============================================
# =============================================
# ('atrium', 'the central room of a Roman house')
# =============================================
# ('atrocious', 'extremely wicked, brutal, or cruel : barbaric')
# =============================================
# ('atrophy:1', 'decrease in size or wasting away of a body part or tissue; also : arrested development or loss of a part or organ incidental to the normal development or life of an animal or plant')
# ('atrophy:2', 'to waste away (as from disease or disuse) : to undergo atrophy; also : to cause (something) to waste away or undergo atrophy')
# =============================================
# ('attaboy', '—used to express encouragement, approval, or admiration')
# =============================================
# ('attach', 'to take by legal authority especially under a writ')
# =============================================
# ('attraction', 'the act, process, or power of attracting')
# ('capillary attraction', 'the force of adhesion between a solid and a liquid in capillarity')
# ('star attraction', 'the person or thing that people most want to see')
# =============================================
# ('auburn:1', 'of the color auburn')
# ('auburn:2', 'a moderate brown')
# ('Auburn:g', 'city in eastern Alabama population 53,380')
# =============================================
# ('audit:1', "a formal examination of an organization's or individual's accounts or financial situation")
# ('audit:2', 'to perform an audit of or for')
# ('audit trail', 'a record of a sequence of events (such as actions performed by a computer) from which a history may be reconstructed')
# =============================================
# ('audition:1', 'the power or sense of hearing')
# ('audition:2', 'to test or try out especially in an audition')
# =============================================
# ('Augean', 'extremely formidable or difficult and occasionally distasteful')
# ('Augean stable', 'a condition or place marked by great accumulation of filth or corruption')
# =============================================
# ('auk', 'any of several black-and-white short-necked diving seabirds of the alcid family that breed in colder parts of the northern hemisphere')
# ('great auk', 'an extinct large flightless auk (Pinguinus impennis) formerly abundant along North Atlantic coasts')
# ('razorbill', 'a North Atlantic auk (Alca torda) with the plumage black above and white below and a compressed sharp-edged bill —called also razor-billed auk')
# =============================================
# ('aureate', 'of a golden color or brilliance')
# =============================================
# ...
# ('viscous', 'having a thick or sticky consistency : viscid')
# =============================================
# ('vise:1', 'any of various tools with two jaws for holding work that close usually by a screw, lever, or cam')
# ('vise:2', 'to hold, force, or squeeze with or as if with a vise')
# ('vise:3', 'visa')
# ('vise:4', 'visa')
# ('vice:2', 'visa')
# =============================================
# ('visual:1', 'of, relating to, or used in vision')
# ('visually impaired', 'unable to see well')
# =============================================
# =============================================
# ('vocation', 'a summons or strong inclination to a particular state or course of action; especially : a divine call to the religious life')
# ("miss one's vocation", 'to not have the career one should have')
# =============================================
# =============================================
# ('volatile:1', 'characterized by or subject to rapid or unexpected change')
# ('volatile:2', 'a substance that is readily vaporizable at relatively low temperature : a volatile substance')
# ('volatile oil', 'an oil that vaporizes readily; especially : essential oil')
# ('sal volatile', 'smelling salts')
# =============================================
# ('vole:1', 'any of various small rodents (Microtus and related genera) that typically have a stout body, rather blunt nose, and short ears, inhabit both moist meadows and dry uplands and do much damage to crops, and are closely related to muskrats and lemmings')
# ('vole:2', 'grand slam')
# ('meadow vole', 'any of various voles (genus Microtus) that frequent open fields; especially : one (M. pennsylvanicus) that is widespread in North America —called also meadow mouse')
# =============================================
# ('volumetric', 'of, relating to, or involving the measurement of volume')
# =============================================
# ('vomitory', 'an entrance piercing the banks of seats of a theater, amphitheater, or stadium')
# =============================================
# ('vorlage', 'the position of a skier leaning forward from the ankles usually without lifting the heels from the skis')
# =============================================
# ('votary', 'devotee')
# =============================================
# ('vulnerable', 'capable of being physically or emotionally wounded')
# =============================================
# ('walleyed', 'having walleyes or affected with walleye')
# ('walleye', 'an eye with a whitish or bluish-white iris')
# =============================================
# ('wamble:1', 'to feel nausea')
# ('wamble:2', 'a wambling especially of the stomach')
# =============================================
# ('warlock', 'a man practicing the black arts : sorcerer')
# =============================================
# ('warlord', 'a supreme military leader')
# =============================================
# ('warp:1', 'a series of yarns extended lengthwise in a loom and crossed by the weft')
# ('warp:2', 'to arrange (yarns) so as to form a warp')
# ('warp and woof', 'foundation, base')
# ('warp beam', 'a roll on which warp is wound for a loom')
# ('warp knit', 'a knit fabric produced by machine with the yarns running in a lengthwise direction')
# ('warp speed', 'the highest possible speed')
# ('time warp', 'an anomaly, discontinuity, or suspension held to occur in the progress of time')
# =============================================
# ('warrant:1', 'sanction, authorization; also : evidence for or token of authorization')
# ('warrant:2', 'to declare or maintain with certainty : be sure that')
# ('warrant officer', 'an officer in the armed forces holding rank by virtue of a warrant and ranking above a noncommissioned officer and below a commissioned officer')
# ('bench warrant', 'a warrant issued by a presiding judge or by a court against a person guilty of contempt or indicted for a crime')
# ('chief warrant officer', 'a warrant officer of senior rank in the armed forces; also : a commissioned officer in the navy or coast guard ranking below an ensign')
# ('death warrant', 'a warrant for the execution of a death sentence')
# ('search warrant', 'a warrant authorizing a search (as of a house) for stolen goods or unlawful possessions')
# ("sign one's own death warrant", "to do something that will cause one's own death")
# =============================================
# ('warren', 'a place legally authorized for keeping small game (such as hare or pheasant)')
# ('Warren:b1', 'Earl 1891—1974 American jurist; chief justice U.S. Supreme Court (1953—69)')
# ('Warren:b2', 'Gouverneur Kemble 1830—1882 American general')
# ('Warren:b3', 'Joseph 1741—1775 American physician and general in Revolution')
# ('Warren:b4', 'J. Robin 1937— Australian pathologist')
# ('Warren:b5', 'Robert Penn 1905—1989 American author and educator; poet laureate (1986—87)')
# ('Warren:g', 'city in southeastern Michigan north of Detroit population 134,056')
# ('rabbit warren', 'warren')
# ('Buffett:b', 'Warren (Edward) 1930— American investor and philanthropist')
# ('Burger:b1', 'Warren Earl 1907—1995 American jurist; chief justice U.S. Supreme Court (1969—86)')
# =============================================
# ('wattle:1', 'a fabrication of poles interwoven with slender branches, withes, or reeds and used especially formerly in building')
# ('wattle:2', 'to form or build of or with wattle')
# ('wattle:3', 'a fleshy pendulous process usually about the head or neck (as of a bird)')
# ('wattle and daub', 'a framework of woven rods and twigs covered and plastered with clay and used in building construction')
# =============================================
# ('wedel', 'to ski by means of wedeln')
# =============================================
# =============================================
# =============================================
# ('wettable', 'capable of being wetted')
# =============================================
# ('wheaten:1', 'of, relating to, or made of wheat')
# ('wheaten:2', 'a pale yellowish to ruddy-fawn color characteristic of the coat of some dogs')
# ('soft-coated wheaten terrier', 'any of a breed of compact medium-sized terriers developed in Ireland and having a soft abundant light fawn coat')
# =============================================
# ('whilom:1', 'formerly')
# ('whilom:2', 'former')
# =============================================
# ('whisk:1', 'a quick light brushing or whipping motion')
# ('whisk:2', 'to move nimbly and quickly')
# ('whisk broom', 'a small broom with a short handle used especially for light cleaning or as a clothes brush')
# ('fly whisk', 'a whisk for brushing away flies')
# =============================================
# ('whodunit', 'a detective story or mystery story')
# =============================================
# ('wicket', 'a small gate or door; especially : one forming part of or placed near a larger gate or door')
# ('sticky wicket', 'a difficult or delicate problem or situation')
# =============================================
# =============================================
# ('willowware', 'dinnerware that is usually blue and white and that is decorated with a story-telling design featuring a large willow tree by a little bridge')
# =============================================
# ('windjammer', 'a sailing ship; also : one of its crew')
# =============================================
# ('win:1', 'to get possession of by effort or fortune')
# =============================================
# ('woad', 'a European herb (Isatis tinctoria) of the mustard family formerly grown for the blue dyestuff yielded by its leaves; also : this dyestuff')
# =============================================
# ('woebegone', 'strongly affected with woe : woeful')
# =============================================
# ('woodchuck', 'a grizzled thickset marmot (Marmota monax) chiefly of Alaska, Canada, and the northeastern U.S. —called also groundhog')
# =============================================
# ('wordy', 'using or containing many and usually too many words')
# =============================================
# ('worthy:1', 'having worth or value : estimable')
# ('worthy:2', 'a worthy or prominent person')
# ('-worthy', 'fit or safe for')
# ('worthy of belief', 'believable : deserving to be believed')
# ('worthy of', 'good enough to have been written, said, done, or created by (someone, especially someone famous)')
# =============================================
# ('wrangle:1', 'to dispute angrily or peevishly : bicker')
# ('wrangle:2', 'an angry, noisy, or prolonged dispute or quarrel')
# =============================================
# ('wrench:1', 'to move with a violent twist; also : to undergo twisting')
# ('wrench:2', 'a violent twisting or a pull with or as if with twisting')
# ('Allen wrench', 'an L-shaped hexagonal metal bar either end of which fits the socket of a screw or bolt')
# ('monkey wrench', 'a wrench with one fixed and one adjustable jaw at right angles to a straight handle')
# ('pipe wrench', 'a wrench for gripping and turning a cylindrical object (such as a pipe) usually by use of two serrated jaws so designed as to grip the pipe when turning in one direction only')
# ('socket wrench', 'a wrench usually in the form of a bar and removable socket made to fit a bolt or nut')
# ('throw a wrench into the works', 'to damage or change (something) in a way that ruins it or prevents it from working properly')
# ('throw/hurl/toss a monkey wrench into', 'to damage or change (something) in a way that ruins it or prevents it from working properly')
# =============================================
# ('wrestle:1', 'to contend by grappling with and striving to trip or throw an opponent down or off balance')
# ('wrestle:2', 'the action or an instance of wrestling : struggle; especially : a wrestling bout')
# ('Indian-wrestle', 'to engage in Indian wrestling')
# =============================================
# ('wretched', 'deeply afflicted, dejected, or distressed in body or mind')
# =============================================
# ('wrinkle:1', 'a small ridge or furrow especially when formed on a surface by the shrinking or contraction of a smooth substance : crease; specifically : one in the skin especially when due to age, worry, or fatigue')
# ('wrinkle:2', 'to become marked with or contracted into wrinkles')
# ('anti-wrinkle', 'intended to reduce the appearance of wrinkles in the skin')
# =============================================
# ('writhe', 'to twist into coils or folds')
# =============================================
# =============================================
# =============================================
# ('xylography', 'the art of making engravings on wood especially for printing')
# =============================================
# =============================================
# ('yachtsman', 'a person who owns or sails a yacht')
# =============================================
# ('yakitori', 'bite-size marinated pieces of beef, seafood, or chicken on skewers')
# =============================================
# ('Yarborough', 'a hand in bridge or whist containing no ace and no card higher than a nine')
# =============================================
# ('yeoman', 'an attendant or officer in a royal or noble household')
# ('yeoman of the guard', 'a member of a military corps attached to the British royal household that serves as ceremonial attendants of the sovereign')
# ('yeoman warder', 'beefeater')
# ("yeoman's/yeoman work/service", 'very good, hard, and valuable work that someone does especially to support a cause, to help a team, etc.')
# =============================================
# ('yew', 'any of a genus (Taxus of the family Taxaceae, the yew family) of evergreen gymnospermous trees and shrubs with stiff linear leaves and seeds surrounded by a fleshy red aril: such as')
# ('English yew', 'yew')
# ('Pacific yew', 'a small or medium slow-growing irregularly branched yew (Taxus brevifolia) of the Pacific coast of the U.S. and Canada that yields a fine-grained hardwood and is the source of paclitaxel')
# =============================================
# ('yore', 'time past and especially long past —usually used in the phrase of yore')
# ('of yore', 'of the past')
# =============================================
# ('yttrium', 'a metallic element with atomic number 39 usually included in the rare-earth group that occurs usually with other rare earth elements in minerals and is used especially in phosphors, YAG lasers, alloys, and treatments for certain cancers')
# =============================================
# =============================================
# ('zephyr', 'a breeze from the west')
# =============================================
# ('zilch', 'zero, nothing')
# =============================================
# ('ziti', 'medium-sized tubular pasta')
# =============================================
# ('zonal', 'of, relating to, affecting, or having the form of a zone')
# ('interzonal', 'occurring between, existing between, or involving two or more zones')
# =============================================
# ('zoology', 'a branch of biology concerned with the classification and the properties and vital phenomena of animals')
# =============================================
# ('Zoroastrianism', 'a Persian religion founded in the sixth century b.c. by the prophet Zoroaster, promulgated in the Avesta, and characterized by worship of a supreme god Ahura Mazda who requires good deeds for help in his cosmic struggle against the evil spirit Ahriman')
# =============================================
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /var/folders/64/rp2jr10901n6vdvhsbn1fz7c0000gn/T/ipykernel_95825/1822908744.py in <module>
#      88 for w in words_without_meaning:
#      89     #print(df_all.loc[df_all['Word']==w,'Short Definition'].values[0])
# ---> 90     words.loc[words['Word']==w,'Meaning'] = df_all.loc[df_all['Word']==w,'Short Definition'].values
#      91 #return words, df_all
#      92
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexing.py in __setitem__(self, key, value)
#     721
#     722         iloc = self if self.name == "iloc" else self.obj.iloc
# --> 723         iloc._setitem_with_indexer(indexer, value, self.name)
#     724
#     725     def _validate_key(self, key, axis: int):
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexing.py in _setitem_with_indexer(self, indexer, value, name)
#    1730             self._setitem_with_indexer_split_path(indexer, value, name)
#    1731         else:
# -> 1732             self._setitem_single_block(indexer, value, name)
#    1733
#    1734     def _setitem_with_indexer_split_path(self, indexer, value, name: str):
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexing.py in _setitem_single_block(self, indexer, value, name)
#    1966
#    1967         # actually do the set
# -> 1968         self.obj._mgr = self.obj._mgr.setitem(indexer=indexer, value=value)
#    1969         self.obj._maybe_update_cacher(clear=True)
#    1970
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/internals/managers.py in setitem(self, indexer, value)
#     353
#     354     def setitem(self: T, indexer, value) -> T:
# --> 355         return self.apply("setitem", indexer=indexer, value=value)
#     356
#     357     def putmask(self, mask, new, align: bool = True):
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/internals/managers.py in apply(self, f, align_keys, ignore_failures, **kwargs)
#     325                     applied = b.apply(f, **kwargs)
#     326                 else:
# --> 327                     applied = getattr(b, f)(**kwargs)
#     328             except (TypeError, NotImplementedError):
#     329                 if not ignore_failures:
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/internals/blocks.py in setitem(self, indexer, value)
#     951             # setting a single element for each dim and with a rhs that could
#     952             #  be e.g. a list; see GH#6043
# --> 953             values[indexer] = value
#     954
#     955         elif exact_match and is_categorical_dtype(arr_value.dtype):
#
# ValueError: shape mismatch: value array of shape (0,)  could not be broadcast to indexing result of shape (1,)

# %%
df_all
# Out:
#                 Word                                   Short Definition
# 0            abalone  any of a genus (Haliotis) of edible rock-cling...
# 1           abdicate  to renounce a throne, high office, dignity, or...
# 2          abduction  the action of abducting : the condition of bei...
# 3           ablution  the washing of one's body or part of it (as in...
# 4         abnormal:1  deviating from the normal or average; often : ...
# ...              ...                                                ...
# 5842            ziti                         medium-sized tubular pasta
# 5843           zonal  of, relating to, affecting, or having the form...
# 5844      interzonal  occurring between, existing between, or involv...
# 5845         zoology  a branch of biology concerned with the classif...
# 5846  Zoroastrianism  a Persian religion founded in the sixth centur...
#
# [5847 rows x 2 columns]

# %%
df_all.fillna('Meaning', inplace=True)

# %%
#words_without_meaning
for w in words_without_meaning:
    print(w)
print(df_all[['Word','Short Definition']].values)
# Out:
# abnormal
# aborad
# aboriginally
# absolution
# abstention
# academe
# academia
# academician
# acanthus
# accipiter
# acclamation
# accommodation
# accomplice
# accretionary
# accumulate
# acedia
# acetabulum
# acetic
# acetone
# acetylcholine
# acharya
# Achillean
# achondroplasia
# acicula
# acolyte
# acoustics
# acrocyanosis
# acrolect
# actinide
# adder
# adherend
# adios
# adjournment
# adminicle
# admonish
# adobe
# adobo
# adolescence
# Adonis
# adonize
# adustiosis
# adversary
# aebleskive
# aerodromics
# aerodynamic
# aerolithology
# aeronautic
# aerosol
# Aesculapian
# Aesir
# Aesopian
# affidavit
# affinity
# afflatus
# agalloch
# agape
# agate
# aggie
# agglutinate
# aggregate
# agnostic
# agonal
# agrarianism
# agronomy
# ahimsa
# ahorse
# aiguillette
# aileron
# Ailurus
# aioli
# aition
# alabaster
# alchemy
# alcove
# aldehyde
# alderman
# aldosterone
# alembic
# alfalfa
# algid
# alias
# alibi
# alison
# alkaline
# alkane
# allotropic
# allure
# alpaca
# alpenglow
# alstroemeria
# altarpiece
# altiplano
# alveolar
# alyssum
# amalgam
# amandine
# amass
# amaurosis
# ambrosia
# ambush
# amercement
# amigo
# amine
# ammoniac
# ammunition
# amnesty
# amorino
# amorphous
# amphibious
# amphoteric
# amygdaline
# anabasis
# anachronism
# anaglyph
# anamnesis
# anarchy
# anastomosis
# anathema
# ancestor
# anchovy
# ancient
# ancilla
# andante
# anemobiagraph
# anemochore
# anemology
# anglaise
# angst
# anhydrous
# animadversion
# animism
# anionic
# anneal
# annexation
# anniversary
# annulet
# anon
# anschluss
# Antaean
# antagonist
# ante
# antebellum
# antecessor
# antediluvian
# antenati
# anticlimax
# antiquarian
# antiquity
# aoristic
# aorta
# aparejo
# aphasia
# apodictic
# Apollonian
# apostate
# apostle
# apotheosis
# apparatchik
# apparentement
# appeasement
# appellate
# appetitost
# appliquer
# apprehend
# aqua
# aqueous
# aquiline
# arabesque
# arachnoid
# arachnophagous
# arboriculture
# arbutus
# arcaded
# arcane
# archaic
# archangel
# archery
# architecture
# architrave
# archizoic
# argent
# argonaut
# arietta
# armada
# armadillo
# armaments
# armature
# armiger
# armistice
# arrears
# arrestee
# arrondissement
# arsenic
# arson
# artery
# Arthurian
# articulate
# artillery
# aryepiglottic
# aryl
# ascension
# asphodel
# aspic
# assassination
# assault
# assemble
# assignment
# assisi
# asterisk
# astrologer
# asynchrony
# atlas
# atmogenic
# atmospheric
# atrament
# atrium
# atrocious
# atrophy
# attaboy
# attachable
# attraction
# auburn
# audit
# audition
# Augean
# auk
# aureate
# aureole
# auricle
# auteur
# autonomous
# autopsy
# autumnal
# avalanche
# avgolemono
# awkward
# axel
# axiom
# axletree
# ayatollah
# ayuntamiento
# azalea
# Aztec
# azure
# babushka
# backgammon
# badminton
# bagatelle
# baignoire
# bailey
# baldmoney
# Balearic
# ballabile
# ballast
# ballistic
# ballistics
# ballot
# ballotage
# banderilla
# banditry
# banquette
# barbellate
# shingles
# shipwreck
# shoal
# shogi
# shogunate
# shorthanded
# showily
# showstopper
# shrapnel
# shrine
# shuttlecock
# sibilance
# siccative
# siege
# sierra
# sigillate
# signet
# signorina
# silane
# silhouette
# silica
# silicicolous
# sillar
# simper
# simulcast
# simultaneously
# sinew
# singleton
# singular
# sinistral
# Sinology
# sitology
# situs
# skerry
# skeuomorph
# skewbald
# skimeister
# skirmish
# skirret
# skittish
# skua
# skyjacking
# slalom
# slander
# slapstick
# slaughter
# sleight
# sleuth
# sluggard
# smaragdine
# smattering
# smelt
# smithereens
# smithy
# smorgasbord
# snipe
# snood
# snooker
# snowbound
# sockeye
# soiree
# solder
# solecism
# solicit
# soliloquy
# solipsistic
# solitaire
# solon
# solstitial
# solvent
# somatopleure
# sombra
# sonatina
# sonobuoy
# sorcerer
# sorrel
# sortie
# souchong
# southpaw
# soviet
# speedball
# speleology
# sphenoidal
# sphincter
# sphinx
# spiedino
# spinet
# spinnaker
# splanchnic
# spleen
# splendid
# spraddle
# springerle
# sprinkling
# spry
# squabble
# squadron
# squall
# squandering
# squatter
# squeaker
# squire
# stadium
# stagnant
# stakeout
# stalemate
# stallion
# stalwart
# stamen
# stamina
# stanchion
# standard
# standing
# stannous
# staple
# starboard
# statesmanship
# station
# stationary
# stationery
# statistics
# statuary
# status
# steel
# steeplechase
# stellated
# stellular
# stentorian
# stereophonic
# sterling
# sternum
# steroid
# stet
# stichomythia
# stilt
# stimulus
# stipple
# stoat
# stockade
# Stockholm
# stoma
# stool
# storage
# stradiot
# strafe
# stratagem
# strategy
# stratocracy
# strephosymbolia
# stridulated
# stroganoff
# stronghold
# strudel
# stucco
# studious
# stupa
# stupefy
# stupor
# stygian
# stylopharyngeus
# sublime
# subornation
# subsequent
# subservience
# subshell
# subsidy
# substantiate
# substitute
# subtrahend
# succinct
# sucrose
# suction
# sudadero
# suerte
# suet
# suffragette
# sukiyaki
# sultanate
# summability
# summitry
# summons
# sumo
# suncatcher
# supercilious
# supercool
# superimposable
# superlative
# supernal
# supernumerary
# surveillance
# susceptible
# susurration
# suzerain
# swaraj
# Swedes
# syllabus
# symphonette
# synapse
# synarchy
# synchroneity
# synchronization
# syndesmosis
# syndicalism
# syndicate
# synthesize
# syringeal
# syrinx
# syssel
# tabard
# tabernacle
# tableau
# tachytely
# tack
# tactically
# tagliatelle
# tallage
# Talmud
# talons
# tandoori
# tanistry
# tantalize
# Taoism
# tapestried
# taphonomy
# tariff
# tarriance
# tassel
# taupe
# tawny
# taxonomy
# teal
# tearjerker
# telemark
# teleological
# telepathic
# televangelist
# tempura
# tenacious
# tenancy
# tendency
# tendon
# tenebrosity
# tenon
# tenpins
# tentacle
# tephra
# teratology
# tercentenary
# tergiversation
# terminus
# termolecular
# ternary
# testify
# tetherball
# tetrachloride
# tetrahedral
# tetralemma
# thaumatology
# thearchic
# theatricality
# theodicy
# theology
# thereabouts
# theretofore
# theriatrics
# thermochemical
# thermonuclear
# thespian
# thievery
# thirdborough
# thorough
# thrice
# thrush
# thumbscrew
# Thyestean
# thyme
# thyroarytenoid
# thyroid
# tichodrome
# tichorrhine
# tiepin
# tiers
# tiki
# tilak
# tilde
# tilleul
# timbale
# timework
# timeworn
# timoneer
# timorously
# tincture
# tinge
# tinnitus
# tinselry
# tintinnabulary
# tithe
# tithingman
# titian
# titration
# Tivoli
# tobogganer
# toccatina
# toehold
# toggle
# toile
# tomatillo
# tooling
# toparchy
# topaz
# topiary
# toploftical
# torero
# tormentil
# torpedo
# torsade
# tortellini
# totem
# touchline
# tournament
# tournedos
# toxicology
# tracery
# tracheal
# tragedienne
# traitor
# trans
# transgression
# trapezoid
# traverse
# treacherous
# treason
# trebuchet
# trecento
# trefoil
# tremolo
# trencher
# trepanation
# trey
# tribology
# triceratops
# trichology
# trichotomy
# triclinic
# tridental
# trierarchy
# trifecta
# trifurcate
# triglycerides
# trigonometry
# trilogy
# trimming
# trimolecular
# trinity
# trinket
# tripartite
# triskelion
# Triton
# triumvirate
# trochanter
# troika
# tropomyosin
# trousseau
# truffled
# trumeau
# trump
# truss
# tryptophanase
# tryst
# tundra
# tungsten
# turnbuckle
# turret
# tutelage
# twain
# typhlology
# tyrannis
# tyrant
# ubiquitous
# ultimatum
# ultimo
# ultramarine
# umber
# umbilical
# umpire
# unappeasable
# uncouth
# unction
# underclass
# undercook
# understudy
# undulate
# unfulfilled
# unify
# unique
# univalent
# unprincipled
# unreadable
# untimely
# uproar
# usher
# usurped
# utilitarian
# uvula
# vacherin
# vagabonds
# vagrancy
# vainly
# vair
# valence
# valet
# vanadium
# vandalism
# vanguard
# vaporer
# vaporetto
# vaporize
# varicella
# variegated
# varnish
# vascular
# vassal
# Vatican
# vaudeville
# veal
# Veda
# vegetarian
# vein
# velodrome
# venerable
# ventifact
# ventilate
# ventricle
# venue
# verbally
# verbena
# verdant
# verdigris
# verdure
# verisimilitude
# vermicelli
# vermiculated
# vermin
# vernacular
# vernal
# versicle
# versicle
# versicolor
# verso
# vertebral
# vesicle
# vesta
# veterans
# vexillary
# vibratiuncle
# vicegerent
# vicennial
# vicissitude
# videography
# viga
# vigentennial
# vigil
# vigilante
# vigorish
# viking
# villain
# vimineous
# vinaceous
# vinaigrette
# vinculum
# vindaloo
# vindicate
# vinegarroon
# vintage
# violaceous
# violoncello
# virgule
# viridescent
# viridity
# virulence
# viscera
# viscid
# viscount
# viscous
# vise
# visually
# vitrophyre
# vocation
# volador
# volatile
# vole
# volumetric
# vomitory
# vorlage
# votary
# vulnerability
# walleyed
# wamble
# warlock
# warlord
# warp
# warrant
# warren
# wattle
# wedel
# weltpolitik
# Wesak
# wettable
# wheaten
# whilom
# whisk
# whodunit
# wicket
# wiesenboden
# willowware
# windjammer
# winnable
# woad
# woebegone
# woodchuck
# wordiness
# worthy
# wrangle
# wrench
# wrestle
# wretchedness
# wrinkle
# writhe
# xanthic
# xenial
# xylograph
# xysti
# yachtsman
# yakitori
# yarborough
# yeoman
# yew
# yore
# yttrium
# zazen
# zephyr
# zilch
# ziti
# zonal
# zoology
# Zoroastrian
# zugzwang
# [['abalone'
#   'any of a genus (Haliotis) of edible rock-clinging gastropod mollusks that have a flattened shell slightly spiral in form, lined with mother-of-pearl, and with a row of apertures along its outer edge']
#  ['abdicate' 'to renounce a throne, high office, dignity, or function']
#  ['abduction' 'the action of abducting : the condition of being abducted']
#  ...
#  ['interzonal'
#   'occurring between, existing between, or involving two or more zones']
#  ['zoology'
#   'a branch of biology concerned with the classification and the properties and vital phenomena of animals']
#  ['Zoroastrianism'
#   'a Persian religion founded in the sixth century b.c. by the prophet Zoroaster, promulgated in the Avesta, and characterized by worship of a supreme god Ahura Mazda who requires good deeds for help in his cosmic struggle against the evil spirit Ahriman']]

# %%
#df1.reset_index(inplace=True)
df_all.loc[4:6]
# Out:
#                   Word                                   Short Definition
# 4           abnormal:1  deviating from the normal or average; often : ...
# 5           abnormal:2                                 an abnormal person
# 6  abnormal psychology  a branch of psychology concerned with mental a...

# %%
len(df_all)
# Out:
# 5847

# %%
'''for w in words_without_meaning:
    #print(df_all.loc[df_all['Word']==w,'Short Definition'].values[0])
    words.loc[words['Word']==w,'Meaning'] = df_all.loc[df_all['Word']==w,'Short Definition'].values[0]'''
# Out:
# "for w in words_without_meaning:\n    #print(df_all.loc[df_all['Word']==w,'Short Definition'].values[0])\n    words.loc[words['Word']==w,'Meaning'] = df_all.loc[df_all['Word']==w,'Short Definition'].values[0]"

# %%
#df_all['Short Definition'].rename('Meaning', inplace=True)
# Out:
# 0       any of a genus (Haliotis) of edible rock-cling...
# 1       to renounce a throne, high office, dignity, or...
# 2       the action of abducting : the condition of bei...
# 3       the washing of one's body or part of it (as in...
# 4       deviating from the normal or average; often : ...
#                               ...
# 5842                           medium-sized tubular pasta
# 5843    of, relating to, affecting, or having the form...
# 5844    occurring between, existing between, or involv...
# 5845    a branch of biology concerned with the classif...
# 5846    a Persian religion founded in the sixth centur...
# Name: Meaning, Length: 5847, dtype: object

# %%
#words = get_word_meaning_mw(df1, respE)
df_all.rename(columns={'Short Definition':'Meaning'}, inplace=True)

# %%
df_all
# Out:
#                 Word                                            Meaning
# 0            abalone  any of a genus (Haliotis) of edible rock-cling...
# 1           abdicate  to renounce a throne, high office, dignity, or...
# 2          abduction  the action of abducting : the condition of bei...
# 3           ablution  the washing of one's body or part of it (as in...
# 4         abnormal:1  deviating from the normal or average; often : ...
# ...              ...                                                ...
# 5842            ziti                         medium-sized tubular pasta
# 5843           zonal  of, relating to, affecting, or having the form...
# 5844      interzonal  occurring between, existing between, or involv...
# 5845         zoology  a branch of biology concerned with the classif...
# 5846  Zoroastrianism  a Persian religion founded in the sixth centur...
#
# [5847 rows x 2 columns]

# %%
df_merged = pd.merge(left=df1['Word'], right=df_all, how='outer', on='Word')
len(df_merged)
# Out:
# 7087

# %%
writer = pd.ExcelWriter('paideia-1998_with_meanings.xlsx', engine='xlsxwriter')
for i in range(0,7500,500):
    df_merged.iloc[i:i+500,:].to_excel(writer, sheet_name=str(i)+'-'+ str(i+500), index=False)
writer.save()
